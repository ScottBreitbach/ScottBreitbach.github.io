# %% [markdown]
# # Scott Breitbach
# ## Milestone 4: Connecting to an API / Pulling in the Data and Cleaning / Formatting
# ## 20-Feb-2021
# ## DSC540, Weeks 9-10

# %%
import pandas as pd
import requests
# import json
import os
from dotenv import load_dotenv
import urllib

# %%
# %load_ext dotenv
# %dotenv
load_dotenv("BEERMAPPING_KEY")
# Out:
# True

# %% [markdown]
# ### Perform at least 5 data transformation and/or cleansing steps to your website data.
# For Example:
# * Replace Headers
# * Format data into a more readable format
# * Identify outliers and bad data
# * Find duplicates
# * Fix casing or inconsistent values
# * Conduct Fuzzy Matching

# %% [markdown]
# # Nebraska Breweries

# %% [markdown]
# ### My struggle with getting API keys:

# %% [markdown]
# Initially I tried to get an API key to Untappd.com, but they are restrictive in who they offer API keys to and my purposes did not qualify.
# I treid twice in January to request an API from BreweryDB.com, and then learned that they are temporarily not offering API keys, though I did manage to get an API key to their sandbox, which contains a subset of their database.
# My next backup plan was BeerMapping.com. I as able to obtain an API key and I spent a fair amount of time submitting updates to their database for breweries. This week, their website went down, so I went back to BreweryDB's sandbox. Once I got my code figured out for retrieving the data I wanted, I did a search for Nebraska, which returned 0 results. I was able to return a handful of breweries from Colorado, so I know the code was working, unfortunately there were just no Nebraska breweries in the sandbox. [See code here](https://github.com/ScottBreitbach/DSC540/blob/main/Final%20Project/BrewerydbAPI.ipynb)
# It is Sunday morning now and in a last ditch effort, I checked BeerMapping.com again and it appears to be back up!

# %% [markdown]
# ## Use BeerMapping.com API to retrieve data on Nebraska breweries

# %%
apiKey = os.environ.get("BEERMAPPING_KEY")
baseURL = "http://beermapping.com/webservice/"

# %% [markdown]
# #### Retrieve Brewery Data as JSON:

# %%
def getStateBreweries(state):
    '''
    Function to retrieve data about breweries within a US State
    '''
    # Assign URL Service to search by State:
    service = "locstate"
    # Assign search term:
    query = state
    # Assemble URL:
    requestURL = f"{baseURL}{service}/{apiKey}/{query}&s=json"
        # Note '&s=json' appended to return JSON formatted data
    
    response = requests.request("GET", requestURL)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    jsonResponse = response.json()
    
    return jsonResponse

# %% [markdown]
# #### Search by State (2-letter abbr):

# %%
state = str(input("Enter 2-letter US State abbreviation:"))
breweryJSON = getStateBreweries(state)
# Out:
# Enter 2-letter US State abbreviation: NE
# 200

# %% [markdown]
# ## Build a DataFrame from the returned JSON data:

# %% [markdown]
# #### Check the keys from one of the returned JSON dictionaries:

# %%
breweryJSON[0].keys()
# Out:
# dict_keys(['id', 'name', 'status', 'reviewlink', 'proxylink', 'blogmap', 'street', 'city', 'state', 'zip', 'country', 'phone', 'url', 'overall', 'imagecount'])

# %% [markdown]
# #### Use the keys to build a dictionary from the data and return a DataFrame:
# ##### [Replace Headers / Format data into a more readable format]

# %%
def buildBreweryDB(listBreweries):
    '''
    Take a list of Brewery data in JSON format.
    Output a DF with key information about those breweries.
    '''
    # Define an empty dictionary, with keys:
    # [Replace Headers]
    breweryDict = {'BreweryID': [], 'BreweryName': [], 'Type': [], 'ReviewLink': [],
                   'ProxyLink': [], 'Map': [], 'StreetAddress': [], 'City': [],
                   'State': [], 'Zip': [], 'Country': [], 'PhoneNum': [],
                   'Website': [], 'Rating': [], 'ImageCount': []}
    
    for b in listBreweries:
        breweryDict['BreweryID'].append(b['id'])
        breweryDict['BreweryName'].append(b['name'])
        breweryDict['Type'].append(b['status'])
        breweryDict['ReviewLink'].append(b['reviewlink'])
        breweryDict['ProxyLink'].append(b['proxylink'])
        breweryDict['Map'].append(b['blogmap'])
        breweryDict['StreetAddress'].append(b['street'])
        breweryDict['City'].append(b['city'])
        breweryDict['State'].append(b['state'])
        breweryDict['Zip'].append(b['zip'])
        breweryDict['Country'].append(b['country'])
        breweryDict['PhoneNum'].append(b['phone'])
#         breweryDict['Website'].append(b['url'])
        # [Format data into a more readable format]
        breweryDict['Website'].append(urllib.parse.unquote(b['url'])) # Fix parsed URLs
        breweryDict['Rating'].append(b['overall'])
        breweryDict['ImageCount'].append(b['imagecount'])
        
    return pd.DataFrame(breweryDict)

# %%
beerDF = buildBreweryDB(breweryJSON)
beerDF.head()
# Out:
#    BreweryID                BreweryName      Type  \
# 0      21938               5168 Brewing   Brewery
# 1      22335               5168 Taproom  Beer Bar
# 2      21215          Alamo Draft House  Beer Bar
# 3      19644          Backswing Brewing   Brewery
# 4      21194  Backswing Brewing Company   Brewery
#
#                                ReviewLink  \
# 0  https://beermapping.com/location/21938
# 1  https://beermapping.com/location/22335
# 2  https://beermapping.com/location/21215
# 3  https://beermapping.com/location/19644
# 4  https://beermapping.com/location/21194
#
#                                            ProxyLink  \
# 0  http://beermapping.com/maps/proxymaps.php?loci...
# 1  http://beermapping.com/maps/proxymaps.php?loci...
# 2  http://beermapping.com/maps/proxymaps.php?loci...
# 3  http://beermapping.com/maps/proxymaps.php?loci...
# 4  http://beermapping.com/maps/proxymaps.php?loci...
#
#                                                  Map        StreetAddress  \
# 0  http://beermapping.com/maps/blogproxy.php?loci...   5730 Hidcote Drive
# 1  http://beermapping.com/maps/blogproxy.php?loci...   3201 Farnam Street
# 2  http://beermapping.com/maps/blogproxy.php?loci...  12750 Westport Pkwy
# 3  http://beermapping.com/maps/blogproxy.php?loci...    500 W South St #8
# 4  http://beermapping.com/maps/blogproxy.php?loci...    500 W South St #8
#
#        City State    Zip        Country        PhoneNum  \
# 0   Lincoln    NE  68516  United States    402-875-5588
# 1     Omaha    NE  68131  United States    402-934-5168
# 2  La Vista    NE  68138  United States    402-505-9979
# 3   Lincoln    NE  68522  United States  (402) 515-4263
# 4   Lincoln    NE  68522  United States    402-515-4263
#
#                                     Website Rating ImageCount
# 0                                                0          0
# 1               http://www.5168brewing.com/      0          0
# 2              https://drafthouse.com/omaha      0          0
# 3  facebook.com/BackswingBrewingCo/timeline      0          0
# 4                                                0          0

# %% [markdown]
# #### Check what types of beer venues we're dealing with:

# %%
beerDF.Type.unique()
# Out:
# array(['Brewery', 'Beer Bar', 'Beer Store', 'Brewpub', 'Homebrew'],
#       dtype=object)

# %% [markdown]
# #### A quick scan through each type to look for anything concerning:
# ##### [Identify outliers and bad data]

# %%
# beerDF[beerDF['Type'] == 'Brewery']

# %%
# beerDF[beerDF['Type'] == 'Beer Bar']

# %%
# beerDF[beerDF['Type'] == 'Beer Store']

# %%
# beerDF[beerDF['Type'] == 'Brewpub']

# %%
# beerDF[beerDF['Type'] == 'Homebrew']

# %% [markdown]
# Lazlo's in the Lincoln Haymarket is the location for Empyrean Brewing Co and was listed under the 'Beer Bar' category and not under 'Brewery'. I used `beerDF.at[55, 'Type'] = 'Brewery'` to fix the issue, but later located Empyrean Brewing under the 'Brewpub' category, so this code was subsequently removed.

# %% [markdown]
# All of the locations appear to be categorized correctly, so I will create a new DataFrame containing just the 'Brewery' and 'Brewpub' categories.

# %%
beerDF.at[36, 'Type'] = 'Beer Bar'

# %% [markdown]
# I found later that another restaruant owned by the Empyrean Brewery people was categorized as 'Brewery' so I have reclassified it as 'Beer Bar' to match the Lazlo's restaurants.

# %% [markdown]
# #### Create a DataFrame containing only breweries:

# %%
breweryDF = beerDF[(beerDF['Type'] == 'Brewery') | (beerDF['Type'] == 'Brewpub')]
breweryDF.head()
# Out:
#    BreweryID                BreweryName     Type  \
# 0      21938               5168 Brewing  Brewery
# 3      19644          Backswing Brewing  Brewery
# 4      21194  Backswing Brewing Company  Brewery
# 5      14326        Beaver View Brewing  Brewery
# 9      17706             Benson Brewery  Brewpub
#
#                                ReviewLink  \
# 0  https://beermapping.com/location/21938
# 3  https://beermapping.com/location/19644
# 4  https://beermapping.com/location/21194
# 5  https://beermapping.com/location/14326
# 9  https://beermapping.com/location/17706
#
#                                            ProxyLink  \
# 0  http://beermapping.com/maps/proxymaps.php?loci...
# 3  http://beermapping.com/maps/proxymaps.php?loci...
# 4  http://beermapping.com/maps/proxymaps.php?loci...
# 5  http://beermapping.com/maps/proxymaps.php?loci...
# 9  http://beermapping.com/maps/proxymaps.php?loci...
#
#                                                  Map       StreetAddress  \
# 0  http://beermapping.com/maps/blogproxy.php?loci...  5730 Hidcote Drive
# 3  http://beermapping.com/maps/blogproxy.php?loci...   500 W South St #8
# 4  http://beermapping.com/maps/blogproxy.php?loci...   500 W South St #8
# 5  http://beermapping.com/maps/blogproxy.php?loci...   524 S. 4th Street
# 9  http://beermapping.com/maps/blogproxy.php?loci...   6059 Maple Street
#
#       City State    Zip        Country        PhoneNum  \
# 0  Lincoln    NE  68516  United States    402-875-5588
# 3  Lincoln    NE  68522  United States  (402) 515-4263
# 4  Lincoln    NE  68522  United States    402-515-4263
# 5   Albion    NE  68620  United States
# 9    Omaha    NE  68104  United States  (402) 937-1892
#
#                                     Website Rating ImageCount
# 0                                                0          0
# 3  facebook.com/BackswingBrewingCo/timeline      0          0
# 4                                                0          0
# 5                                                0          0
# 9                         bensonbrewery.com      0          0

# %% [markdown]
# #### Another look over just the brewery names for any outliers:
# ##### [Identify outliers and bad data]

# %%
breweryDF['BreweryName'].unique()
# Out:
# array(['5168 Brewing', 'Backswing Brewing', 'Backswing Brewing Company',
#        'Beaver View Brewing', 'Benson Brewery',
#        'Blue Blood Brewing Company', 'Boiler Brewing Company',
#        'Bolo Beer Co', 'Bootleg Brewers',
#        'Bootleg Brewers / Sandhills Brewing Company',
#        'Bottle Rocket Brewing Company', 'Brickway Brewery and Distillery',
#        'Broken Arrow Cellars and Brewery', 'Brush Creek Brewing Company',
#        'Code Beer Company', 'Cosmic Eye Brewing Company',
#        'Empyrean Ales - Lazlos',
#        'Fairfield Opera House Brewery and Grill',
#        'Farnam House Brewing Company', 'First Street Brewing Company',
#        'Flyover Brewing Company', 'Gottberg Brewpub',
#        'Granite City Food and Brewery - Lincoln',
#        'Granite City Food and Brewery - Omaha',
#        'Infusion Brewing Company', 'Jaipur Restaurant and Brewpub',
#        'Johnnie Byrd Brewing Company', 'Kinkaider Brewing Company',
#        'Lazy Horse Vineyard and Brewery', 'Loop Brewing',
#        'Lost Way Brewery', 'Lucky Bucket Brewing Co',
#        "Misty's Steakhouse And Brewery", 'Nebraska Brewing Company',
#        'Pals Brewing Company', 'Platte Valley Brewery',
#        'Prairie Pride Brewing Company',
#        'Schilling Bridge Winery and Microbrewery',
#        'Scratchtown Brewing Company', 'Scriptown Brewing',
#        'Soaring Wings', 'Spilker Ales', 'Steeple Brewing Company',
#        'The Brewery at Divots', 'Thunderhead Brewing Company',
#        'Upstream Brewing Company', 'Vis Major Brewing Co.',
#        'White Elm Brewing Company', 'Zipline Brewing Company'],
#       dtype=object)

# %% [markdown]
# Data Fixes:
# * [Rename] **5168 Brewing** changed their name to **Catalyst Brewing Co** in 2020.
# * [Remove] **Beaver View**, **Blue Blood**, **Misty's**, and **Spilker** have all closed and should be removed.
# * [No change] **Granite City** is a chain and not a local Nebraska brewery, but it appears I kept it in the previous Milestones so I'll leave it in.
# * [Rename] **Broken Arrow** is the parent winery for **Hanging Horseshoe**
# * [Rename] Remove 'Lazlos' from **Empyrean** as it is the restaurant portion.

# %% [markdown]
# Duplicates:
# * Backswing
# * Bootleg
# * Granite City (keeping for some reason)

# %%
breweryDF['BreweryName'].unique()
# Out:
# array(['5168 Brewing', 'Backswing Brewing', 'Backswing Brewing Company',
#        'Beaver View Brewing', 'Benson Brewery',
#        'Blue Blood Brewing Company', 'Boiler Brewing Company',
#        'Bolo Beer Co', 'Bootleg Brewers',
#        'Bootleg Brewers / Sandhills Brewing Company',
#        'Bottle Rocket Brewing Company', 'Brickway Brewery and Distillery',
#        'Broken Arrow Cellars and Brewery', 'Brush Creek Brewing Company',
#        'Code Beer Company', 'Cosmic Eye Brewing Company',
#        'Empyrean Ales - Lazlos',
#        'Fairfield Opera House Brewery and Grill',
#        'Farnam House Brewing Company', 'First Street Brewing Company',
#        'Flyover Brewing Company', 'Gottberg Brewpub',
#        'Granite City Food and Brewery - Lincoln',
#        'Granite City Food and Brewery - Omaha',
#        'Infusion Brewing Company', 'Jaipur Restaurant and Brewpub',
#        'Johnnie Byrd Brewing Company', 'Kinkaider Brewing Company',
#        'Lazy Horse Vineyard and Brewery', 'Loop Brewing',
#        'Lost Way Brewery', 'Lucky Bucket Brewing Co',
#        "Misty's Steakhouse And Brewery", 'Nebraska Brewing Company',
#        'Pals Brewing Company', 'Platte Valley Brewery',
#        'Prairie Pride Brewing Company',
#        'Schilling Bridge Winery and Microbrewery',
#        'Scratchtown Brewing Company', 'Scriptown Brewing',
#        'Soaring Wings', 'Spilker Ales', 'Steeple Brewing Company',
#        'The Brewery at Divots', 'Thunderhead Brewing Company',
#        'Upstream Brewing Company', 'Vis Major Brewing Co.',
#        'White Elm Brewing Company', 'Zipline Brewing Company'],
#       dtype=object)

# %% [markdown]
# #### Remove closed breweries:

# %%
def removeBreweries(df, col, values):
    '''
    Remove rows based based on values in a specified 
    column that match a list of passed values.
    '''
    return df[df[col].isin(values) == False]

# %%
closed = ['Beaver View Brewing', 'Blue Blood Brewing Company',
         "Misty's Steakhouse And Brewery", 'Spilker Ales']

# %%
len(breweryDF)
# Out:
# 53

# %%
breweryDF = removeBreweries(breweryDF, 'BreweryName', closed)

# %%
len(breweryDF)
# Out:
# 49

# %% [markdown]
# #### Rename some breweries:

# %%
nameChanges = {
    '5168 Brewing': 'Catalyst Brewing Company',
    'Broken Arrow Cellars and Brewery': 'Hanging Horseshoe Brewing Company',
    'Empyrean Ales - Lazlos': 'Empyrean Brewing Company',
}

# %%
def updateNames(df, col, replaceDict):
    '''
    Rename values in a specified column, using a 
    dictonary of old names and new names.
    '''
    for k, v in replaceDict.items():
        df[col].replace(k, v, inplace=True)

# %%
updateNames(breweryDF, 'BreweryName', nameChanges)

# %%
breweryDF.head()
# Out:
#     BreweryID                BreweryName     Type  \
# 0       21938   Catalyst Brewing Company  Brewery
# 3       19644          Backswing Brewing  Brewery
# 4       21194  Backswing Brewing Company  Brewery
# 9       17706             Benson Brewery  Brewpub
# 14      20376     Boiler Brewing Company  Brewery
#
#                                 ReviewLink  \
# 0   https://beermapping.com/location/21938
# 3   https://beermapping.com/location/19644
# 4   https://beermapping.com/location/21194
# 9   https://beermapping.com/location/17706
# 14  https://beermapping.com/location/20376
#
#                                             ProxyLink  \
# 0   http://beermapping.com/maps/proxymaps.php?loci...
# 3   http://beermapping.com/maps/proxymaps.php?loci...
# 4   http://beermapping.com/maps/proxymaps.php?loci...
# 9   http://beermapping.com/maps/proxymaps.php?loci...
# 14  http://beermapping.com/maps/proxymaps.php?loci...
#
#                                                   Map           StreetAddress  \
# 0   http://beermapping.com/maps/blogproxy.php?loci...      5730 Hidcote Drive
# 3   http://beermapping.com/maps/blogproxy.php?loci...       500 W South St #8
# 4   http://beermapping.com/maps/blogproxy.php?loci...       500 W South St #8
# 9   http://beermapping.com/maps/blogproxy.php?loci...       6059 Maple Street
# 14  http://beermapping.com/maps/blogproxy.php?loci...  129 N 10th St, Suite 8
#
#        City State    Zip        Country        PhoneNum  \
# 0   Lincoln    NE  68516  United States    402-875-5588
# 3   Lincoln    NE  68522  United States  (402) 515-4263
# 4   Lincoln    NE  68522  United States    402-515-4263
# 9     Omaha    NE  68104  United States  (402) 937-1892
# 14  Lincoln    NE  68508  United States    402-261-8775
#
#                                      Website Rating ImageCount
# 0                                                 0          0
# 3   facebook.com/BackswingBrewingCo/timeline      0          0
# 4                                                 0          0
# 9                          bensonbrewery.com      0          0
# 14                  boilerbrewingcompany.com      0          0

# %% [markdown]
# #### Check for duplicates:

# %%
breweryDF[breweryDF['BreweryName'].duplicated()]
# Out:
#      BreweryID                  BreweryName     Type  \
# 47       20515     Infusion Brewing Company  Brewery
# 69       18889     Nebraska Brewing Company  Brewery
# 95       16272  Thunderhead Brewing Company  Brewery
# 104      21370      Zipline Brewing Company  Brewery
#
#                                  ReviewLink  \
# 47   https://beermapping.com/location/20515
# 69   https://beermapping.com/location/18889
# 95   https://beermapping.com/location/16272
# 104  https://beermapping.com/location/21370
#
#                                              ProxyLink  \
# 47   http://beermapping.com/maps/proxymaps.php?loci...
# 69   http://beermapping.com/maps/proxymaps.php?loci...
# 95   http://beermapping.com/maps/proxymaps.php?loci...
# 104  http://beermapping.com/maps/proxymaps.php?loci...
#
#                                                    Map  \
# 47   http://beermapping.com/maps/blogproxy.php?loci...
# 69   http://beermapping.com/maps/blogproxy.php?loci...
# 95   http://beermapping.com/maps/blogproxy.php?loci...
# 104  http://beermapping.com/maps/blogproxy.php?loci...
#
#                StreetAddress      City State    Zip        Country  \
# 47   6271 South 118th Street     Omaha    NE  68137  United States
# 69           6950 S 108th St  La Vista    NE  68128  United States
# 95              201 Avenue F    Axtell    NE  68924  United States
# 104            721 N 14th St     Omaha    NE  68102  United States
#
#            PhoneNum                     Website Rating ImageCount
# 47     402-934-2064         infusionbrewing.com      0          0
# 69                        nebraskabrewingco.com      0          0
# 95   (308) 237-1558      thunderheadbrewing.com      0          0
# 104                  http://ziplinebrewing.com/      0          0

# %%
breweryDF[breweryDF['BreweryName'] == 'Nebraska Brewing Company']
# Out:
#     BreweryID               BreweryName     Type  \
# 68       7136  Nebraska Brewing Company  Brewpub
# 69      18889  Nebraska Brewing Company  Brewery
#
#                                 ReviewLink  \
# 68   https://beermapping.com/location/7136
# 69  https://beermapping.com/location/18889
#
#                                             ProxyLink  \
# 68  http://beermapping.com/maps/proxymaps.php?loci...
# 69  http://beermapping.com/maps/proxymaps.php?loci...
#
#                                                   Map  \
# 68  http://beermapping.com/maps/blogproxy.php?loci...
# 69  http://beermapping.com/maps/blogproxy.php?loci...
#
#                         StreetAddress       City State    Zip        Country  \
# 68  7474 Towne Center Pkwy. Suite 101  Papillion    NE  68046  United States
# 69                    6950 S 108th St   La Vista    NE  68128  United States
#
#           PhoneNum                Website     Rating ImageCount
# 68  (402) 934-7100  nebraskabrewingco.com  91.666675          8
# 69                  nebraskabrewingco.com          0          0

# %%
breweryDF.iloc[1:3]
# Out:
#    BreweryID                BreweryName     Type  \
# 3      19644          Backswing Brewing  Brewery
# 4      21194  Backswing Brewing Company  Brewery
#
#                                ReviewLink  \
# 3  https://beermapping.com/location/19644
# 4  https://beermapping.com/location/21194
#
#                                            ProxyLink  \
# 3  http://beermapping.com/maps/proxymaps.php?loci...
# 4  http://beermapping.com/maps/proxymaps.php?loci...
#
#                                                  Map      StreetAddress  \
# 3  http://beermapping.com/maps/blogproxy.php?loci...  500 W South St #8
# 4  http://beermapping.com/maps/blogproxy.php?loci...  500 W South St #8
#
#       City State    Zip        Country        PhoneNum  \
# 3  Lincoln    NE  68522  United States  (402) 515-4263
# 4  Lincoln    NE  68522  United States    402-515-4263
#
#                                     Website Rating ImageCount
# 3  facebook.com/BackswingBrewingCo/timeline      0          0
# 4                                                0          0

# %% [markdown]
# Checking the duplicates, I found that one of Nebraska Brewing Company's locations has closed (Papillion) and Backswing Brewing is in there twice, under slightly different names.
# I will delete the closed Nebraska Brewing location as well as the second Backswing because it has less information available. I will then rename it to match.

# %%
removeID = [7136, 21194]
breweryDF = removeBreweries(breweryDF, 'BreweryID', removeID)

# %%
rename = {'Backswing Brewing': 'Backswing Brewing Co.'}
updateNames(breweryDF, 'BreweryName', rename)

# %%
print(breweryDF[['BreweryID', "BreweryName"]])
# Out:
#      BreweryID                                  BreweryName
# 0        21938                     Catalyst Brewing Company
# 3        19644                        Backswing Brewing Co.
# 9        17706                               Benson Brewery
# 14       20376                       Boiler Brewing Company
# 15       20287                                 Bolo Beer Co
# 16       20835                              Bootleg Brewers
# 17       21191  Bootleg Brewers / Sandhills Brewing Company
# 18       20099                Bottle Rocket Brewing Company
# 20       18888              Brickway Brewery and Distillery
# 21       19643            Hanging Horseshoe Brewing Company
# 22       20832                  Brush Creek Brewing Company
# 25       21721                            Code Beer Company
# 26       22356                   Cosmic Eye Brewing Company
# 32         417                     Empyrean Brewing Company
# 33       20101      Fairfield Opera House Brewery and Grill
# 34       19001                 Farnam House Brewing Company
# 37       20801                 First Street Brewing Company
# 38       22330                      Flyover Brewing Company
# 39         519                             Gottberg Brewpub
# 40         530      Granite City Food and Brewery - Lincoln
# 41        3740        Granite City Food and Brewery - Omaha
# 46       18081                     Infusion Brewing Company
# 47       20515                     Infusion Brewing Company
# 48         685                Jaipur Restaurant and Brewpub
# 52       21775                 Johnnie Byrd Brewing Company
# 53       19390                    Kinkaider Brewing Company
# 58       20080              Lazy Horse Vineyard and Brewery
# 63       14327                                 Loop Brewing
# 64       21777                             Lost Way Brewery
# 66       10511                      Lucky Bucket Brewing Co
# 69       18889                     Nebraska Brewing Company
# 79       21316                         Pals Brewing Company
# 81        1012                        Platte Valley Brewery
# 82       20833                Prairie Pride Brewing Company
# 83        3113     Schilling Bridge Winery and Microbrewery
# 84       15203                  Scratchtown Brewing Company
# 85       19366                            Scriptown Brewing
# 86       14325                                Soaring Wings
# 89       21776                      Steeple Brewing Company
# 90       20079                        The Brewery at Divots
# 94        1326                  Thunderhead Brewing Company
# 95       16272                  Thunderhead Brewing Company
# 97        1374                     Upstream Brewing Company
# 98       21720                        Vis Major Brewing Co.
# 99       21193                    White Elm Brewing Company
# 103      16511                      Zipline Brewing Company
# 104      21370                      Zipline Brewing Company

# %% [markdown]
# Discovered another duplicate (Bootleg). Researched and removed as appropriate.

# %%
removeID = [20835]
breweryDF = removeBreweries(breweryDF, 'BreweryID', removeID)

# %%
breweryDF
# Out:
#      BreweryID                                  BreweryName     Type  \
# 0        21938                     Catalyst Brewing Company  Brewery
# 3        19644                        Backswing Brewing Co.  Brewery
# 9        17706                               Benson Brewery  Brewpub
# 14       20376                       Boiler Brewing Company  Brewery
# 15       20287                                 Bolo Beer Co  Brewery
# 17       21191  Bootleg Brewers / Sandhills Brewing Company  Brewpub
# 18       20099                Bottle Rocket Brewing Company  Brewery
# 20       18888              Brickway Brewery and Distillery  Brewery
# 21       19643            Hanging Horseshoe Brewing Company  Brewery
# 22       20832                  Brush Creek Brewing Company  Brewpub
# 25       21721                            Code Beer Company  Brewpub
# 26       22356                   Cosmic Eye Brewing Company  Brewery
# 32         417                     Empyrean Brewing Company  Brewpub
# 33       20101      Fairfield Opera House Brewery and Grill  Brewpub
# 34       19001                 Farnam House Brewing Company  Brewpub
# 37       20801                 First Street Brewing Company  Brewery
# 38       22330                      Flyover Brewing Company  Brewpub
# 39         519                             Gottberg Brewpub  Brewpub
# 40         530      Granite City Food and Brewery - Lincoln  Brewpub
# 41        3740        Granite City Food and Brewery - Omaha  Brewpub
# 46       18081                     Infusion Brewing Company  Brewery
# 47       20515                     Infusion Brewing Company  Brewery
# 48         685                Jaipur Restaurant and Brewpub  Brewpub
# 52       21775                 Johnnie Byrd Brewing Company  Brewpub
# 53       19390                    Kinkaider Brewing Company  Brewery
# 58       20080              Lazy Horse Vineyard and Brewery  Brewpub
# 63       14327                                 Loop Brewing  Brewpub
# 64       21777                             Lost Way Brewery  Brewpub
# 66       10511                      Lucky Bucket Brewing Co  Brewery
# 69       18889                     Nebraska Brewing Company  Brewery
# 79       21316                         Pals Brewing Company  Brewpub
# 81        1012                        Platte Valley Brewery  Brewpub
# 82       20833                Prairie Pride Brewing Company  Brewery
# 83        3113     Schilling Bridge Winery and Microbrewery  Brewery
# 84       15203                  Scratchtown Brewing Company  Brewery
# 85       19366                            Scriptown Brewing  Brewery
# 86       14325                                Soaring Wings  Brewery
# 89       21776                      Steeple Brewing Company  Brewpub
# 90       20079                        The Brewery at Divots  Brewpub
# 94        1326                  Thunderhead Brewing Company  Brewpub
# 95       16272                  Thunderhead Brewing Company  Brewery
# 97        1374                     Upstream Brewing Company  Brewpub
# 98       21720                        Vis Major Brewing Co.  Brewpub
# 99       21193                    White Elm Brewing Company  Brewery
# 103      16511                      Zipline Brewing Company  Brewery
# 104      21370                      Zipline Brewing Company  Brewery
#
#                                  ReviewLink  \
# 0    https://beermapping.com/location/21938
# 3    https://beermapping.com/location/19644
# 9    https://beermapping.com/location/17706
# 14   https://beermapping.com/location/20376
# 15   https://beermapping.com/location/20287
# 17   https://beermapping.com/location/21191
# 18   https://beermapping.com/location/20099
# 20   https://beermapping.com/location/18888
# 21   https://beermapping.com/location/19643
# 22   https://beermapping.com/location/20832
# 25   https://beermapping.com/location/21721
# 26   https://beermapping.com/location/22356
# 32     https://beermapping.com/location/417
# 33   https://beermapping.com/location/20101
# 34   https://beermapping.com/location/19001
# 37   https://beermapping.com/location/20801
# 38   https://beermapping.com/location/22330
# 39     https://beermapping.com/location/519
# 40     https://beermapping.com/location/530
# 41    https://beermapping.com/location/3740
# 46   https://beermapping.com/location/18081
# 47   https://beermapping.com/location/20515
# 48     https://beermapping.com/location/685
# 52   https://beermapping.com/location/21775
# 53   https://beermapping.com/location/19390
# 58   https://beermapping.com/location/20080
# 63   https://beermapping.com/location/14327
# 64   https://beermapping.com/location/21777
# 66   https://beermapping.com/location/10511
# 69   https://beermapping.com/location/18889
# 79   https://beermapping.com/location/21316
# 81    https://beermapping.com/location/1012
# 82   https://beermapping.com/location/20833
# 83    https://beermapping.com/location/3113
# 84   https://beermapping.com/location/15203
# 85   https://beermapping.com/location/19366
# 86   https://beermapping.com/location/14325
# 89   https://beermapping.com/location/21776
# 90   https://beermapping.com/location/20079
# 94    https://beermapping.com/location/1326
# 95   https://beermapping.com/location/16272
# 97    https://beermapping.com/location/1374
# 98   https://beermapping.com/location/21720
# 99   https://beermapping.com/location/21193
# 103  https://beermapping.com/location/16511
# 104  https://beermapping.com/location/21370
#
#                                              ProxyLink  \
# 0    http://beermapping.com/maps/proxymaps.php?loci...
# 3    http://beermapping.com/maps/proxymaps.php?loci...
# 9    http://beermapping.com/maps/proxymaps.php?loci...
# 14   http://beermapping.com/maps/proxymaps.php?loci...
# 15   http://beermapping.com/maps/proxymaps.php?loci...
# 17   http://beermapping.com/maps/proxymaps.php?loci...
# 18   http://beermapping.com/maps/proxymaps.php?loci...
# 20   http://beermapping.com/maps/proxymaps.php?loci...
# 21   http://beermapping.com/maps/proxymaps.php?loci...
# 22   http://beermapping.com/maps/proxymaps.php?loci...
# 25   http://beermapping.com/maps/proxymaps.php?loci...
# 26   http://beermapping.com/maps/proxymaps.php?loci...
# 32   http://beermapping.com/maps/proxymaps.php?loci...
# 33   http://beermapping.com/maps/proxymaps.php?loci...
# 34   http://beermapping.com/maps/proxymaps.php?loci...
# 37   http://beermapping.com/maps/proxymaps.php?loci...
# 38   http://beermapping.com/maps/proxymaps.php?loci...
# 39   http://beermapping.com/maps/proxymaps.php?loci...
# 40   http://beermapping.com/maps/proxymaps.php?loci...
# 41   http://beermapping.com/maps/proxymaps.php?loci...
# 46   http://beermapping.com/maps/proxymaps.php?loci...
# 47   http://beermapping.com/maps/proxymaps.php?loci...
# 48   http://beermapping.com/maps/proxymaps.php?loci...
# 52   http://beermapping.com/maps/proxymaps.php?loci...
# 53   http://beermapping.com/maps/proxymaps.php?loci...
# 58   http://beermapping.com/maps/proxymaps.php?loci...
# 63   http://beermapping.com/maps/proxymaps.php?loci...
# 64   http://beermapping.com/maps/proxymaps.php?loci...
# 66   http://beermapping.com/maps/proxymaps.php?loci...
# 69   http://beermapping.com/maps/proxymaps.php?loci...
# 79   http://beermapping.com/maps/proxymaps.php?loci...
# 81   http://beermapping.com/maps/proxymaps.php?loci...
# 82   http://beermapping.com/maps/proxymaps.php?loci...
# 83   http://beermapping.com/maps/proxymaps.php?loci...
# 84   http://beermapping.com/maps/proxymaps.php?loci...
# 85   http://beermapping.com/maps/proxymaps.php?loci...
# 86   http://beermapping.com/maps/proxymaps.php?loci...
# 89   http://beermapping.com/maps/proxymaps.php?loci...
# 90   http://beermapping.com/maps/proxymaps.php?loci...
# 94   http://beermapping.com/maps/proxymaps.php?loci...
# 95   http://beermapping.com/maps/proxymaps.php?loci...
# 97   http://beermapping.com/maps/proxymaps.php?loci...
# 98   http://beermapping.com/maps/proxymaps.php?loci...
# 99   http://beermapping.com/maps/proxymaps.php?loci...
# 103  http://beermapping.com/maps/proxymaps.php?loci...
# 104  http://beermapping.com/maps/proxymaps.php?loci...
#
#                                                    Map  \
# 0    http://beermapping.com/maps/blogproxy.php?loci...
# 3    http://beermapping.com/maps/blogproxy.php?loci...
# 9    http://beermapping.com/maps/blogproxy.php?loci...
# 14   http://beermapping.com/maps/blogproxy.php?loci...
# 15   http://beermapping.com/maps/blogproxy.php?loci...
# 17   http://beermapping.com/maps/blogproxy.php?loci...
# 18   http://beermapping.com/maps/blogproxy.php?loci...
# 20   http://beermapping.com/maps/blogproxy.php?loci...
# 21   http://beermapping.com/maps/blogproxy.php?loci...
# 22   http://beermapping.com/maps/blogproxy.php?loci...
# 25   http://beermapping.com/maps/blogproxy.php?loci...
# 26   http://beermapping.com/maps/blogproxy.php?loci...
# 32   http://beermapping.com/maps/blogproxy.php?loci...
# 33   http://beermapping.com/maps/blogproxy.php?loci...
# 34   http://beermapping.com/maps/blogproxy.php?loci...
# 37   http://beermapping.com/maps/blogproxy.php?loci...
# 38   http://beermapping.com/maps/blogproxy.php?loci...
# 39   http://beermapping.com/maps/blogproxy.php?loci...
# 40   http://beermapping.com/maps/blogproxy.php?loci...
# 41   http://beermapping.com/maps/blogproxy.php?loci...
# 46   http://beermapping.com/maps/blogproxy.php?loci...
# 47   http://beermapping.com/maps/blogproxy.php?loci...
# 48   http://beermapping.com/maps/blogproxy.php?loci...
# 52   http://beermapping.com/maps/blogproxy.php?loci...
# 53   http://beermapping.com/maps/blogproxy.php?loci...
# 58   http://beermapping.com/maps/blogproxy.php?loci...
# 63   http://beermapping.com/maps/blogproxy.php?loci...
# 64   http://beermapping.com/maps/blogproxy.php?loci...
# 66   http://beermapping.com/maps/blogproxy.php?loci...
# 69   http://beermapping.com/maps/blogproxy.php?loci...
# 79   http://beermapping.com/maps/blogproxy.php?loci...
# 81   http://beermapping.com/maps/blogproxy.php?loci...
# 82   http://beermapping.com/maps/blogproxy.php?loci...
# 83   http://beermapping.com/maps/blogproxy.php?loci...
# 84   http://beermapping.com/maps/blogproxy.php?loci...
# 85   http://beermapping.com/maps/blogproxy.php?loci...
# 86   http://beermapping.com/maps/blogproxy.php?loci...
# 89   http://beermapping.com/maps/blogproxy.php?loci...
# 90   http://beermapping.com/maps/blogproxy.php?loci...
# 94   http://beermapping.com/maps/blogproxy.php?loci...
# 95   http://beermapping.com/maps/blogproxy.php?loci...
# 97   http://beermapping.com/maps/blogproxy.php?loci...
# 98   http://beermapping.com/maps/blogproxy.php?loci...
# 99   http://beermapping.com/maps/blogproxy.php?loci...
# 103  http://beermapping.com/maps/blogproxy.php?loci...
# 104  http://beermapping.com/maps/blogproxy.php?loci...
#
#                     StreetAddress          City State    Zip        Country  \
# 0              5730 Hidcote Drive       Lincoln    NE  68516  United States
# 3               500 W South St #8       Lincoln    NE  68522  United States
# 9               6059 Maple Street         Omaha    NE  68104  United States
# 14         129 N 10th St, Suite 8       Lincoln    NE  68508  United States
# 15                420 East 1st St     Valentine    NE  69201  United States
# 17                 45145 829th Rd        Taylor    NE  68879  United States
# 18              230 S. 5th Street        Seward    NE  68434  United States
# 20            1116 Jackson Street         Omaha    NE  68102  United States
# 21                73892 332nd ave      Imperial    NE  69033  United States
# 22             102 N. Main Street      Atkinson    NE  68713  United States
# 25     200 S Antelope Valley Pkwy       Lincoln    NE  68508  United States
# 26                 6800 P St #300       Lincoln    NE  68505  United States
# 32                      729 Q St.       Lincoln    NE  68508  United States
# 33             415 North D Street     Fairfield    NE  68938  United States
# 34             3558 Farnam Street         Omaha    NE  68131  United States
# 37            119 N St Joseph Ave      Hastings    NE  68901  United States
# 38                  1824 Broadway   Scottsbluff    NE  69361  United States
# 39               2804 13th Street      Columbus    NE  68601  United States
# 40                  6150 O Street       Lincoln    NE  68505  United States
# 41              1001 N. 102nd St.         Omaha    NE  68114  United States
# 46              6115 Maple Street         Omaha    NE  68104  United States
# 47        6271 South 118th Street         Omaha    NE  68137  United States
# 48                  10922 Elm St.         Omaha    NE  68144  United States
# 52                 121 N Pearl St         Wayne    NE  68787  United States
# 53             43860 Paulsen Road    Broken Bow    NE  68822  United States
# 58                    211 Road 20        Ohiowa    NE  68416  United States
# 63              404 West A Street        McCook    NE  69001  United States
# 64                    614 3rd Ave      Holdrege    NE  68949  United States
# 66   11941 Centennial Road, Ste 1      La Vista    NE  68128  United States
# 69                6950 S 108th St      La Vista    NE  68128  United States
# 79       4520 S. Buffalo Bill Ave  North Platte    NE  69101  United States
# 81                 14 E. Railroad       Kearney    NE  68847  United States
# 82      115 E. South Front Street  Grand Island    NE  68801  United States
# 83                     710th Road   Pawnee City    NE  68420  United States
# 84                  141 S 16th St           Ord    NE  68862  United States
# 85             3922 Farnam Street         Omaha    NE  68131  United States
# 86         17111 So. 138th street   Springfield    NE  68059  United States
# 89          717 West First Street      Hastings    NE  68901  United States
# 90          4200 West Norfolk Ave       Norfolk    NE  68701  United States
# 94            18 East 21st Street       Kearney    NE  68847  United States
# 95                   201 Avenue F        Axtell    NE  68924  United States
# 97          514 South 11th Street         Omaha    NE  68102  United States
# 98             3501 Center Street         Omaha    NE  68105  United States
# 99                  2717 S 8th St       Lincoln    NE  68502  United States
# 103     2100 Magnum Circle, Ste 1       Lincoln    NE  68522  United States
# 104                 721 N 14th St         Omaha    NE  68102  United States
#
#             PhoneNum                                            Website  \
# 0       402-875-5588
# 3     (402) 515-4263           facebook.com/BackswingBrewingCo/timeline
# 9     (402) 937-1892                                  bensonbrewery.com
# 14      402-261-8775                           boilerbrewingcompany.com
# 15                                              facebook.com/BoloBeerCo
# 17      308-942-3440                                 bootlegbrewers.com
# 18                                              bottlerocketbrewing.com
# 20    (402) 933-2613                      http://www.drinkbrickway.com/
# 21     ﻿308-882-7772  facebook.com/pages/Broken-Arrow-Cellars/793194...
# 22                               facebook.com/BrushCreekBrewingCompany/
# 25    (402) 318-5888                            http://www.codebeer.co/
# 26      531-500-2739                        https://www.cosmiceye.beer/
# 32    (402) 434-5959                          telesis-inc.com/empyrean/
# 33      402-726-2447                            fairfieldoperahouse.com
# 34                                               farnamhousebrewing.com
# 37                                               firststreetbrewing.com
# 38                                        www.flyoverbrewingcompany.com
# 39    (402) 562-6488                             dustersrestaurant.com/
# 40    (402) 466-1900                                          gcfb.net/
# 41      402-393-5000                                          gcfb.net/
# 46    (402) 916-9998                                infusionbrewing.com
# 47      402-934-2064                                infusionbrewing.com
# 48   (402) 392-7331
# 52      402-833-1522                       http://www.johnniebyrd.beer/
# 53      308-872-8348                               kinkaiderbrewing.com
# 58      402-295-2550                               lazyhorsebrewing.com
# 63      308-737-9921                             loopbrewingcompany.com
# 64      308-995-0503                         http://lostwaybrewery.com/
# 66    (402) 763-8868                             luckybucketbrewing.com
# 69                                                nebraskabrewingco.com
# 79      308-221-6715                             palsbrewingcompany.com
# 81    (308) 237-0751                    http://www.theplattevalley.com/
# 82      308-850-5375                            prairiepridebrewery.com
# 83      402-852-2400                          schillingbridgewinery.com
# 84    (308) 730-2376            facebook.com/scratchtownbrewing?sk=wall
# 85      402-991-0506                               scriptownbrewing.com
# 86    (402) 253-2479                               soaringwingswine.com
# 89      402-519-4205                         http://steeplebrewing.com/
# 90      402-379-3833                               divotsconference.com
# 94    (308) 237-1558                            thunderheadbrewing.com/
# 95    (308) 237-1558                             thunderheadbrewing.com
# 97    (402) 344-0200                               upstreambrewing.com/
# 98    (402) 884-4082                            www.vismajorbrewing.com
# 99      402-261-6078                                whiteelmbrewing.com
# 103   (402) 450-9804                                 ziplinebrewing.com
# 104                                          http://ziplinebrewing.com/
#
#        Rating ImageCount
# 0           0          0
# 3           0          0
# 9           0          0
# 14          0          0
# 15          0          0
# 17          0          0
# 18          0          0
# 20    93.3334          1
# 21          0          0
# 22          0          0
# 25          0          0
# 26          0          0
# 32          0          6
# 33          0          0
# 34          0          0
# 37          0          0
# 38          0          0
# 39          0          0
# 40          0          0
# 41          0          0
# 46          0          0
# 47          0          0
# 48   71.66645          0
# 52          0          0
# 53          0          0
# 58          0          0
# 63          0          1
# 64          0          0
# 66        100          0
# 69          0          0
# 79          0          0
# 81          0          0
# 82          0          0
# 83   71.66665          5
# 84          0          0
# 85          0          0
# 86          0          0
# 89          0          0
# 90          0          0
# 94          0          0
# 95          0          0
# 97    83.3334          5
# 98          0          0
# 99          0          0
# 103         0          0
# 104         0          0

# %% [markdown]
# #### Reset the index:

# %%
breweryDF.reset_index(drop=True, inplace=True)

# %% [markdown]
# #### Save as CSV:

# %%
breweryDF.to_csv('API_beerMapping.csv', index=False)

# %%
import urllib.request
r = urllib.request.urlopen('https://en.wikipedia.org/wiki/Neighborhoods_of_Omaha,_Nebraska')

# %%
import urllib.request
import ssl


def main():
    ssl._create_default_https_context = ssl._create_unverified_context
    r = urllib.request.urlopen('https://en.wikipedia.org/wiki/Neighborhoods_of_Omaha,_Nebraska')
    print(r.status)
    print(r)


if __name__ == '__main__':
    main()
# Out:
# 200
# <http.client.HTTPResponse object at 0x000001701A045CA0>

# %%
omahaSubs
# Out:
# ['Aksarben/Elmwood Park',
#  'Aksarben Village',
#  'Applewood',
#  'Armbrust Acres',
#  'Baker Place',
#  'Barrington Park',
#  'Bemis Park',
#  'Bennington',
#  'Benson',
#  'Bent Creek',
#  'Blackstone',
#  'Boys Town',
#  'Briar Hills',
#  'Bridlewood',
#  'Broadwood Heights-Golden Valley',
#  'Brookhaven',
#  'Buena Vista',
#  'Burlington Road',
#  'Burnt District',
#  'Cathedral Landmark District',
#  'Carter Lake',
#  'Chalco',
#  'Conestoga Place',
#  'Country Club',
#  'Dahlman',
#  'Deer Park',
#  'Dundee',
#  'Eagle Ridge',
#  'Eagle Run',
#  'Elkhorn',
#  'Elmwood Park',
#  'Fairacres',
#  'Five Fountains',
#  'Florence',
#  'Field Club',
#  'First National Business Park',
#  'Fountain Hills',
#  'Gifford Park',
#  'Gold Coast',
#  'Greenfields',
#  'Green Meadows',
#  'Hanscom Park',
#  'Happy Hollow',
#  'Harvey Oaks',
#  'Hillsborough',
#  'Howard Street Apartment District',
#  'Huntington Park',
#  'Indian Hills Village',
#  'Irvington',
#  'Keystone',
#  'Kountze Place',
#  'La Vista',
#  'Leawood Southwest',
#  'Leavenworth',
#  'Linden Park-Lindenwood',
#  'Little Bohemia',
#  'Little Italy',
#  'Maple Village',
#  'Meridian Park',
#  'Midtown Crossing',
#  'Millard',
#  'Miller Park',
#  'Minne Lusa',
#  'Morton Meadows',
#  'Mockingbird Heights',
#  'Near North Side',
#  'Oak Heights',
#  'Old Gold Coast',
#  'Old Market Historic District',
#  'Omaha View',
#  'Orchard Hill',
#  'Original Montclair (Omaha)',
#  'Pacific Hollow',
#  'Pacific Meadows',
#  'Pacific Park',
#  'Papillion',
#  'Park Avenue',
#  'Park East',
#  'Pepperwood',
#  'Prospect Hill',
#  'Ralston',
#  'Raven Oaks',
#  'Roanoke',
#  'Robin Hill',
#  'Royalwood Estates',
#  'Regency',
#  'Roxbury',
#  'Saratoga',
#  'Sheelytown',
#  'South Omaha Main Street Historic District',
#  'Sporting District',
#  'Spring Lake',
#  "Squatter's Row",
#  'Sunny Slope',
#  'Trendwood',
#  'Valley',
#  'Vinton Street Commercial Historic District',
#  'Walnut Hill',
#  'Waterloo',
#  'Wedgewood',
#  'West Farnam neighborhood',
#  'Westgate',
#  'Westside',
#  'Windridge Hills']
