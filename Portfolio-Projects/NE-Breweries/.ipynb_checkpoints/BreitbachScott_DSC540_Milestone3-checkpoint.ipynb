# %% [markdown]
# # Scott Breitbach
# ## Milestone 3: Cleaning / Formatting Website Data
# ## 06-Feb-2021
# ## DSC540, Weeks 7-8

# %%
# pip install fuzzywuzzy

# %%
# pip install python-Levenshtein

# %%
import pandas as pd
import requests
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %% [markdown]
# ### Perform at least 5 data transformation and/or cleansing steps to your website data.
# For Example:
# * Replace Headers
# * Format data into a more readable format
# * Identify outliers and bad data
# * Find duplicates
# * Fix casing or inconsistent values
# * Conduct Fuzzy Matching

# %%
# url = requests.get("https://www.reddit.com/r/nebraskabeer/wiki/beer_list")
# soup = BeautifulSoup(url.content, 'html.parser')

# %% [markdown]
# \<html lang="en-US">
# -\<body style="zoom: 1;">
# --\<div id="2x-container">
# ---\<div class="... id="SHORTCUT...
# ----\<div class="SubredditVars...
# -----\<div class="...
# ------\<div>
# -------\<div class="...
# --------\<div class="...
# ---------\<div style="max-width... class="...
# ----------\<div class="...
# -----------\<div class="...
# ------------\<div class="...
# -------------\<div class="md wiki">
# --------------\<table>
# ---------------\<thead>...\</thead>
# ----------------\<tr>...\</tr>
# ---------------\<tbody>...\</tbody>
# ----------------\<tr>...\</tr>  # one for each row
# --------------\</table

# %%
# print(soup.prettify())

# %% [markdown]
# ## 1) Import Website Data

# %%
# This didn't work all the time so I added some redundancy:
try:
    listOfDF = pd.read_html("https://www.reddit.com/r/nebraskabeer/wiki/beer_list")
except:
    try:
        listOfDF = pd.read_html("https://www.reddit.com/r/nebraskabeer/wiki/beer_list")
    except:
        try:
            listOfDF = pd.read_html("https://www.reddit.com/r/nebraskabeer/wiki/beer_list")
        except:
            print("Failed to connect; try again later.")
# Out:
# Failed to connect; try again later.

# %%
numTables = len(listOfDF)
print("There are {} tables on the page.".format(numTables))
# Out:
# There are 7 tables on the page.

# %% [markdown]
# ### Find the correct table

# %%
listOfDF[0].head(3)
# Out:
#              Brewery Name                       City Type of Brewery  \
# 0   Backswing Brewing Co.                    Lincoln           Micro
# 1          Benson Brewery                      Omaha         Taproom
# 2  Boiler Brewing Company  Lincoln / Lincoln - South         Taproom
#
#                             Type of Distribution  \
# 0  On-tap at the brewery and at select locations
# 1                     On tap only at the brewery
# 2                     On tap only at the brewery
#
#                                                Notes
# 0                            Distro planned for 2016
# 1  Other beers, locals included, on tap. Omaha Br...
# 2                            Tours posted on FB page

# %% [markdown]
# #### That's the one. Assign to dataframe:

# %%
breweriesDF = listOfDF[0]

# %% [markdown]
# ### Get an overview of the data:

# %%
breweriesDF.describe()
# Out:
#                        Brewery Name   City Type of Brewery  \
# count                            55     55              55
# unique                           55     42               5
# top     Granite City Food & Brewery  Omaha         Brewpub
# freq                              1      4              19
#
#          Type of Distribution   Notes
# count                      47      34
# unique                     21      33
# top     On tap at the brewery  Winery
# freq                       15       2

# %% [markdown]
# ## 2) Identify Null Values

# %%
breweriesDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Brewery Name          55 non-null     object
#  1   City                  55 non-null     object
#  2   Type of Brewery       55 non-null     object
#  3   Type of Distribution  47 non-null     object
#  4   Notes                 34 non-null     object
# dtypes: object(5)
# memory usage: 2.3+ KB

# %% [markdown]
# #### No null values in Name, City, or Type.
# Notes and Distribution are okay to have nulls, though I may update Distro info if I can find a reliable source.

# %% [markdown]
# ## 3) Replace Headers

# %%
oldCols = breweriesDF.columns
newCols = ['Brewery Name', 'City', 'Type of Brewery', 
           'Type of Distribution', 'Notes']

# %%
breweriesDF.columns = newCols

# %%
breweriesDF.columns
# Out:
# Index(['Brewery Name', 'City', 'Type of Brewery', 'Type of Distribution',
#        'Notes'],
#       dtype='object')

# %%
# breweriesDF.head(3)

# %% [markdown]
# ## 4) Check for Duplicates (by column)

# %%
print("Duplicates in:")
for name in breweriesDF.columns:
    print("{:.<40}".format(name), any(breweriesDF[name].duplicated()))
# Out:
# Duplicates in:
# Brewery Name............................ False
# City.................................... True
# Type of Brewery......................... True
# Type of Distribution.................... True
# Notes................................... True

# %% [markdown]
# #### All brewery names are unique. Other duplicates are okay.

# %% [markdown]
# ## 5) Get brewery counts by City

# %%
breweriesDF['City'].value_counts()
# Out:
# Omaha                                                                                                      4
# Lincoln                                                                                                    4
# LaVista                                                                                                    3
# Kearney                                                                                                    2
# Omaha - Midtown                                                                                            2
# Omaha - Downtown                                                                                           2
# North Platte                                                                                               2
# Hastings                                                                                                   2
# Columbus                                                                                                   1
# Elkhorn                                                                                                    1
# Pawnee City / Lincoln                                                                                      1
# Lincoln / Lincoln - South                                                                                  1
# Holdrege                                                                                                   1
# Wayne                                                                                                      1
# Lincoln - West / Lincoln - SE (Beer Hall) / Omaha - West (Beer Lounge) / Omaha - Downtown (Culture Lab)    1
# Benson / Omaha - SW / Omaha - Little Bohemia / Omaha - The Switch                                          1
# Albion                                                                                                     1
# Valentine                                                                                                  1
# Beatrice                                                                                                   1
# Broken Bow / Grand Island / Lincoln                                                                        1
# Omaha / Lincoln                                                                                            1
# Norfolk                                                                                                    1
# Springfield                                                                                                1
# Omaha - West                                                                                               1
# Seward                                                                                                     1
# Atkinson                                                                                                   1
# Lincoln - Haymarket                                                                                        1
# Alliance                                                                                                   1
# Kearney / Omaha - West / Omaha - Downtown / Axtell                                                         1
# Taylor                                                                                                     1
# Grand Island                                                                                               1
# Fairfield                                                                                                  1
# Ohiowa                                                                                                     1
# Lincoln / Lincoln - Haymarket                                                                              1
# McCook                                                                                                     1
# Imperial                                                                                                   1
# Scottsbluff                                                                                                1
# Lexington                                                                                                  1
# Syracuse                                                                                                   1
# Papillion                                                                                                  1
# Johnson Lake                                                                                               1
# Ord                                                                                                        1
# Name: City, dtype: int64

# %% [markdown]
# #### As expected, the larger cities have more breweries, which is good.
# However, some breweries appear to have multiple locations, which is problematic.
# I can either separate them into individual locations or just use the primary location for each.
# Since my interest is in the breweries themselves, I think I will assign the primary location and add a column showing the number of locations per brewery.

# %% [markdown]
# ### Get Count of locations for breweries:

# %%
breweriesDF = breweriesDF.rename(columns={'City':'Locations'})

# %%
breweriesDF['# Locations'] = breweriesDF['Locations'].str.count('/') + 1

# %%
breweriesDF.head(3)
# Out:
#              Brewery Name                  Locations Type of Brewery  \
# 0   Backswing Brewing Co.                    Lincoln           Micro
# 1          Benson Brewery                      Omaha         Taproom
# 2  Boiler Brewing Company  Lincoln / Lincoln - South         Taproom
#
#                             Type of Distribution  \
# 0  On-tap at the brewery and at select locations
# 1                     On tap only at the brewery
# 2                     On tap only at the brewery
#
#                                                Notes  # Locations
# 0                            Distro planned for 2016            1
# 1  Other beers, locals included, on tap. Omaha Br...            1
# 2                            Tours posted on FB page            2

# %% [markdown]
# ## 6) Get Primary city for each brewery:
# Note: Keeping the column with all locations. Might be useful.

# %%
breweriesDF['City'] = breweriesDF['Locations'].str.partition('/')[0]

# %%
breweriesDF['City'] = breweriesDF['City'].str.partition('-')[0]

# %%
breweriesDF['City'] = breweriesDF['City'].str.strip()

# %%
# # This can be used to split the multiple locations into a list:
# breweriesDF['Locations'] = breweriesDF['Locations'].str.split('/')

# %%
breweriesDF.head(3)
# Out:
#              Brewery Name                  Locations Type of Brewery  \
# 0   Backswing Brewing Co.                    Lincoln           Micro
# 1          Benson Brewery                      Omaha         Taproom
# 2  Boiler Brewing Company  Lincoln / Lincoln - South         Taproom
#
#                             Type of Distribution  \
# 0  On-tap at the brewery and at select locations
# 1                     On tap only at the brewery
# 2                     On tap only at the brewery
#
#                                                Notes  # Locations     City
# 0                            Distro planned for 2016            1  Lincoln
# 1  Other beers, locals included, on tap. Omaha Br...            1    Omaha
# 2                            Tours posted on FB page            2  Lincoln

# %% [markdown]
# #### Add State column:
# Redundant, but could be useful.

# %%
breweriesDF['State'] = 'Nebraska'

# %% [markdown]
# #### Rearrange columns:

# %%
dfCols = breweriesDF.columns
dfCols
# Out:
# Index(['Brewery Name', 'Locations', 'Type of Brewery', 'Type of Distribution',
#        'Notes', '# Locations', 'City', 'State'],
#       dtype='object')

# %%
newColOrder = ['Brewery Name', 'City', 'State', 'Type of Brewery', 
               'Type of Distribution', 'Notes', '# Locations', 'Locations']
breweriesDF = breweriesDF[newColOrder]

# %%
breweriesDF.head(3)
# Out:
#              Brewery Name     City     State Type of Brewery  \
# 0   Backswing Brewing Co.  Lincoln  Nebraska           Micro
# 1          Benson Brewery    Omaha  Nebraska         Taproom
# 2  Boiler Brewing Company  Lincoln  Nebraska         Taproom
#
#                             Type of Distribution  \
# 0  On-tap at the brewery and at select locations
# 1                     On tap only at the brewery
# 2                     On tap only at the brewery
#
#                                                Notes  # Locations  \
# 0                            Distro planned for 2016            1
# 1  Other beers, locals included, on tap. Omaha Br...            1
# 2                            Tours posted on FB page            2
#
#                    Locations
# 0                    Lincoln
# 1                      Omaha
# 2  Lincoln / Lincoln - South

# %% [markdown]
# ## 7) Fuzzy Matching

# %% [markdown]
# For reference:
# https://medium.com/analytics-vidhya/matching-messy-pandas-columns-with-fuzzywuzzy-4adda6c7994f

# %%
# # Save to CSV for testing purposes in other notebook.
# breweriesDF.to_csv('testData.csv', index=False)

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %% [markdown]
# ### Load Data:

# %%
testDF = pd.DataFrame()
checkDF = pd.read_csv('CSV_nebraskaCleaned.csv')
actualDF = pd.read_csv('testData.csv')
testDF['NamesToCheck'] = checkDF['Brewery Name']

# %% [markdown]
# ### Try out multiple FuzzyWuzzy scorers:

# %%
# Set up dictionary of abbreviations for FuzzyWuzzy scorers:
scorer_dict = { 'R':fuzz.ratio, 
                'PR': fuzz.partial_ratio, 
                'TSeR': fuzz.token_set_ratio, 
                'TSoR': fuzz.token_sort_ratio,
                'PTSeR': fuzz.partial_token_set_ratio, 
                'PTSoR': fuzz.partial_token_sort_ratio, 
                'WR': fuzz.WRatio, 
                'QR': fuzz.QRatio,
                'UWR': fuzz.UWRatio, 
                'UQR': fuzz.UQRatio }

# %%
# Input FuzzyWuzzy scorer abbreviation as argument;
# returns DF of matched names and scores, plus average score.

def scorerTesterFunction(x):
    testDF = pd.DataFrame()
    testDF['NamesToCheck'] = checkDF['Brewery Name']
    
    actualName = []
    similarity = []
    
    for i in testDF['NamesToCheck']:
        ratio = process.extract(i, actualDF['Brewery Name'], limit=1,
                               scorer=scorer_dict[x])
        actualName.append(ratio[0][0])
        similarity.append(ratio[0][1])
        
        testDF[x+'Name'] = pd.Series(actualName)
        testDF[x+'Score'] = pd.Series(similarity)
        
    print('Average Score: {0:.2f}'.format(testDF[x+'Score'].mean()))
        
    return testDF.sort_values(x+'Score', ascending=False)

# %% [markdown]
# #### - 'R':

# %%
# scorerTesterFunction('R')

# %% [markdown]
# Off to a good start. There are only two incorrect matches, but looking more closely it makes sense:
# * Blue Blood is closed and I will need to fix that in the cleanup of the other file.
# * Lazlo's is the restaurant associated with Empyrean Brewing. This will also need to be fixed in the other file.
#
# ##### Scorer: `fuzz.ratio`
# ##### Incorrect: 2
# ##### Avg Score: 90.14

# %% [markdown]
# #### - 'PR':

# %%
scorerTesterFunction('PR')
# Out:
# Average Score: 95.48
#                                    NamesToCheck  \
# 0                         Backswing Brewing Co.
# 18            Hanging Horseshoe Brewing Company
# 20                     Infusion Brewing Company
# 1                                Benson Brewery
# 23                         Kinkaider Brewing Co
# 24                  Kros Strain Brewing Company
# 26                           Lazy Horse Brewing
# 27                              Loop Brewing Co
# 28                             Lost Way Brewery
# 29                      Lucky Bucket Brewing Co
# 32                         Pals Brewing Company
# 35                  Scratchtown Brewing Company
# 36                    Scriptown Brewing Company
# 38                           Steeple Brewing Co
# 39                       Thunderhead Brewing Co
# 41                         Vis Major Brewing Co
# 42                         White Elm Brewing Co
# 19                     Infusion Brewing Company
# 22                 Johnnie Byrd Brewing Company
# 17             Granite City Food & Brewery (#7)
# 10                               Divots Brewery
# 3                        Boiler Brewing Company
# 4                                  Bolo Beer Co
# 6                      Bottle Rocket Brewing Co
# 8                   Brush Creek Brewing Company
# 16            Granite City Food & Brewery (#16)
# 9                                 Code Beer Co.
# 43                           Zipline Brewing Co
# 11                          Empyrean Brewing Co
# 12                Fairfield Opera House Brewery
# 13                 Farnam House Brewing Company
# 14                         First Street Brewing
# 15                            Gottberg Brew Pub
# 5   Bootleg Brewers - Sandhills Brewing Company
# 2                    Blue Blood Brewing Company
# 7               Brickway Brewery and Distillery
# 31              Nebraska Brewing Co - Papillion
# 33                        Prairie Pride Brewery
# 30               Nebraska Brewing Co - La Vista
# 40                     Upstream Brewing Co (#1)
# 37                        Soaring Wings Brewing
# 25          Lazlo's Brewery & Grill - Haymarket
# 34        SchillingBridge Winery & Microbrewery
# 21                Jaipur Restaurant and Brewpub
#
#                                     PRName  PRScore
# 0                    Backswing Brewing Co.      100
# 18       Hanging Horseshoe Brewing Company      100
# 20                Infusion Brewing Company      100
# 1                           Benson Brewery      100
# 23               Kinkaider Brewing Company      100
# 24             Kros Strain Brewing Company      100
# 26             Lazy Horse Brewing & Winery      100
# 27                    Loop Brewing Company      100
# 28                        Lost Way Brewery      100
# 29            Lucky Bucket Brewing Company      100
# 32                    Pals Brewing Company      100
# 35             Scratchtown Brewing Company      100
# 36               Scriptown Brewing Company      100
# 38                     Steeple Brewing Co.      100
# 39             Thunderhead Brewing Company      100
# 41               Vis Major Brewing Company      100
# 42               White Elm Brewing Company      100
# 19                Infusion Brewing Company      100
# 22            Johnnie Byrd Brewing Company      100
# 17             Granite City Food & Brewery      100
# 10                          Divots Brewery      100
# 3                   Boiler Brewing Company      100
# 4                            Bolo Beer Co.      100
# 6            Bottle Rocket Brewing Company      100
# 8              Brush Creek Brewing Company      100
# 16             Granite City Food & Brewery      100
# 9                        Code Beer Company      100
# 43                     Zipline Brewing Co.      100
# 11                Empyrean Brewing Company      100
# 12   Fairfield Opera House Brewery & Grill      100
# 13            Farnam House Brewing Company      100
# 14            First Street Brewing Company      100
# 15                       Gottberg Brew Pub      100
# 5   Bootleg Brewers, Sandhills Brewing Co.       97
# 2                     Loop Brewing Company       95
# 7            Brickway Brewery & Distillery       90
# 31                Nebraska Brewing Company       88
# 33           Prairie Pride Brewing Company       86
# 30                Nebraska Brewing Company       83
# 40                Upstream Brewing Company       83
# 37        Soaring Wings Vineyard & Brewing       76
# 25                             Brewery 719       73
# 34         Schillingbridge Brewing Company       71
# 21                  Jaipur Brewing Company       59

# %% [markdown]
# Same two are incorrect.
# ##### Scorer: `fuzz.partial_ratio`
# ##### Incorrect: 2
# ##### Avg Score: 95.48

# %% [markdown]
# #### - 'TSeR':

# %%
# scorerTesterFunction('TSeR')

# %% [markdown]
# Same two incorrect, plus Prairie Pride
# ##### Scorer: `fuzz.token_set_ratio`
# ##### Incorrect: 3
# ##### Avg Score: 93.93

# %% [markdown]
# #### - 'TSoR':

# %%
# scorerTesterFunction('TSoR')

# %% [markdown]
# 2 expected incorrect.
# ##### Scorer: `fuzz.token_sort_ratio`
# ##### Incorrect: 2
# ##### Avg Score: 90.5

# %% [markdown]
# #### - 'PTSeR':

# %%
# scorerTesterFunction('PTSeR')

# %% [markdown]
# Almost entirely incorrect.
# ##### Scorer: `fuzz.partial_token_set_ratio`
# ##### Incorrect: Too numerous to count
# ##### Avg Score: 100

# %% [markdown]
# #### - 'PTSoR':

# %%
# scorerTesterFunction('PTSoR')

# %% [markdown]
# ##### Scorer: `fuzz.partial_token_sort_ratio`
# ##### Incorrect: 7
# ##### Avg Score: 89.09

# %% [markdown]
# #### - 'WR':

# %%
# scorerTesterFunction('WR')

# %% [markdown]
# ##### Scorer: `fuzz.WRatio`
# ##### Incorrect: 8
# ##### Avg Score: 92.66

# %% [markdown]
# #### - 'QR':

# %%
# scorerTesterFunction('QR')

# %% [markdown]
# Expected 2 incorrect.
# ##### Scorer: `fuzz.QRatio`
# ##### Incorrect: 2
# ##### Avg Score: 90.14

# %% [markdown]
# #### - 'UWR':

# %%
# scorerTesterFunction('UWR')

# %% [markdown]
# ##### Scorer: `fuzz.UWRatio`
# ##### Incorrect: 8
# ##### Avg Score: 92.66

# %% [markdown]
# ### - 'UQR':

# %%
# scorerTesterFunction('UQR')

# %% [markdown]
# Expected 2 incorrect.
# ##### Scorer: `fuzz.UQRatio`
# ##### Incorrect: 2
# ##### Avg Score: 90.14

# %% [markdown]
# ### Fuzzy Matching Analysis:
# With the exception of the two breweries that I need to fix, fully half of the 10 FuzzyWuzzy scoring methods gave me satisfactory results. I don't know if averge score is a good way to approach this given that the score appeared to be higher overall on the methods with worse matching, but given that 5 of the methods worked I will go with the `fuzz.partial_ratio` method, which had the highest average score out of that subset. Note: other methods were run, but commented out to save space.

# %%
breweriesDF
# Out:
#                               Brewery Name          City     State  \
# 0                    Backswing Brewing Co.       Lincoln  Nebraska
# 1                           Benson Brewery         Omaha  Nebraska
# 2                   Boiler Brewing Company       Lincoln  Nebraska
# 3                            Bolo Beer Co.     Valentine  Nebraska
# 4   Bootleg Brewers, Sandhills Brewing Co.        Taylor  Nebraska
# 5            Bottle Rocket Brewing Company        Seward  Nebraska
# 6                              Brewery 719      Alliance  Nebraska
# 7            Brickway Brewery & Distillery         Omaha  Nebraska
# 8              Brush Creek Brewing Company      Atkinson  Nebraska
# 9             Canyon Lakes Brewing Company  Johnson Lake  Nebraska
# 10                Catalyst Brewing Company       Lincoln  Nebraska
# 11                       Code Beer Company       Lincoln  Nebraska
# 12                      Cosmic Eye Brewing       Lincoln  Nebraska
# 13                          Divots Brewery       Norfolk  Nebraska
# 14                Empyrean Brewing Company       Lincoln  Nebraska
# 15   Fairfield Opera House Brewery & Grill     Fairfield  Nebraska
# 16            Farnam House Brewing Company         Omaha  Nebraska
# 17            First Street Brewing Company      Hastings  Nebraska
# 18                 Flyover Brewing Company   Scottsbluff  Nebraska
# 19                       Gottberg Brew Pub      Columbus  Nebraska
# 20             Granite City Food & Brewery         Omaha  Nebraska
# 21       Hanging Horseshoe Brewing Company      Imperial  Nebraska
# 22                  Hwy 14 Brewing Company        Albion  Nebraska
# 23                Infusion Brewing Company        Benson  Nebraska
# 24                  Jaipur Brewing Company         Omaha  Nebraska
# 25            Johnnie Byrd Brewing Company         Wayne  Nebraska
# 26                         Jukes Ale Works       Elkhorn  Nebraska
# 27               Kinkaider Brewing Company    Broken Bow  Nebraska
# 28             Kros Strain Brewing Company       LaVista  Nebraska
# 29             Lazy Horse Brewing & Winery        Ohiowa  Nebraska
# 30                    Loop Brewing Company        McCook  Nebraska
# 31                        Lost Way Brewery      Holdrege  Nebraska
# 32            Lucky Bucket Brewing Company       LaVista  Nebraska
# 33            Mac's Creek Winery & Brewery     Lexington  Nebraska
# 34                      Monolithic Brewing         Omaha  Nebraska
# 35                Nebraska Brewing Company       LaVista  Nebraska
# 36                    Pals Brewing Company  North Platte  Nebraska
# 37                 Peg Leg Brewing Company  North Platte  Nebraska
# 38               Pint Nine Brewing Company     Papillion  Nebraska
# 39                   Platte Valley Brewery       Kearney  Nebraska
# 40           Prairie Pride Brewing Company  Grand Island  Nebraska
# 41              Roc Hopper Brewing Company      Syracuse  Nebraska
# 42         Schillingbridge Brewing Company   Pawnee City  Nebraska
# 43             Scratchtown Brewing Company           Ord  Nebraska
# 44               Scriptown Brewing Company         Omaha  Nebraska
# 45                          Site-1 Brewing         Omaha  Nebraska
# 46        Soaring Wings Vineyard & Brewing   Springfield  Nebraska
# 47                     Steeple Brewing Co.      Hastings  Nebraska
# 48            Stone Hollow Brewing Company      Beatrice  Nebraska
# 49             Thunderhead Brewing Company       Kearney  Nebraska
# 50                      Upper Room Brewery       Kearney  Nebraska
# 51                Upstream Brewing Company         Omaha  Nebraska
# 52               Vis Major Brewing Company         Omaha  Nebraska
# 53               White Elm Brewing Company       Lincoln  Nebraska
# 54                     Zipline Brewing Co.       Lincoln  Nebraska
#
#    Type of Brewery                               Type of Distribution  \
# 0            Micro      On-tap at the brewery and at select locations
# 1          Taproom                         On tap only at the brewery
# 2          Taproom                         On tap only at the brewery
# 3          Taproom  On tap at the brewery and select distribution ...
# 4          Brewpub                                       Taproom only
# 5          Taproom                                                NaN
# 6          Taproom                              On-tap at the brewery
# 7            Micro  On tap and select distribution around Omaha; D...
# 8          Brewpub                                                NaN
# 9          Brewpub                              On tap at the brewery
# 10         Brewpub                              On-tap at the brewery
# 11           Micro                              On tap at the brewery
# 12         Taproom                      On tap, crowlers, retail cans
# 13         Brewpub                                                NaN
# 14           Micro                         On tap state-wide, bottles
# 15         Brewpub                                                NaN
# 16         Brewpub                         On tap only at the brewery
# 17         Taproom      On-tap at the brewery and at select locations
# 18         Brewpub                              On tap at the brewery
# 19         Brewpub                         On tap only at the brewery
# 20           Chain                         On tap only at the brewery
# 21         Taproom                                On tap on-site only
# 22           Micro                              On tap at the brewery
# 23           Micro  On tap throughout Omaha and at the brewery, sp...
# 24         Brewpub                         On tap only at the brewery
# 25           Micro                              On tap at the brewery
# 26         Brewpub                                                NaN
# 27           Micro     On tap at the brewery, including crowler fills
# 28           Micro                              On tap at the brewery
# 29         Brewpub                      On tap at the brewery; Winery
# 30         Brewpub                         On tap only at the brewery
# 31         Taproom                                                NaN
# 32           Micro                         On tap state-wide, bottles
# 33         Taproom                              On tap at the brewery
# 34         Brewpub                              On-tap at the brewery
# 35   Micro/Brewpub                On tap state-wide, cans and bottles
# 36         Brewpub                              On tap at the brewery
# 37         Taproom                              On-tap at the brewery
# 38           Micro                              On tap at the brewery
# 39         Brewpub                         On tap at the brewery only
# 40         Taproom                                                NaN
# 41           Micro                                        Distro only
# 42         Brewpub         On tap at the brewery, 4 styles in bottles
# 43         Taproom  On tap at the brewery, limited bottle distribu...
# 44         Taproom             On tap at the brewery and around Omaha
# 45           Micro                              On tap at the brewery
# 46         Taproom                                                NaN
# 47         Taproom                              On tap at the brewery
# 48         Taproom                              On tap at the brewery
# 49         Taproom                            On tap state-wide, cans
# 50           Micro                              On tap at the brewery
# 51         Brewpub                   On tap in Omaha, limited bottles
# 52         Brewpub                              On tap at the brewery
# 53           Micro                              On tap at the brewery
# 54           Micro                         On tap state-wide, bottles
#
#                                                 Notes  # Locations  \
# 0                             Distro planned for 2016            1
# 1   Other beers, locals included, on tap. Omaha Br...            1
# 2                             Tours posted on FB page            2
# 3                                                 NaN            1
# 4                    Steakhouse and lodging available            1
# 5                                    Opened fall 2015            1
# 6                                     Opened Feb 2019            1
# 7                                    formerly Borgata            1
# 8                                                 NaN            1
# 9                                Opened June 19, 2019            1
# 10  Owned by the LOCAL Beer, Patio, & Kitchen folk...            1
# 11                                                NaN            1
# 12                                 Opened 03-Oct-2018            1
# 13  Small brewing operation in the conference cent...            1
# 14                       Oldest Microbrew in Nebraska            1
# 15                                                NaN            1
# 16                                 Formerly Goldenrod            1
# 17                                                NaN            1
# 18                                   Opened Sept 2018            1
# 19                           Root beer and cream soda            1
# 20                                                NaN            2
# 21                Part of Broken Arrow Cellars Winery            1
# 22                                Opened October 2018            1
# 23                           12-15 house-brewed beers            4
# 24                                                NaN            1
# 25  Opened Dec 2017; Nebraska's first benefit corp...            1
# 26                                Opened July 9, 2019            1
# 27                                                NaN            3
# 28                                                NaN            1
# 29                                                NaN            1
# 30                                                NaN            1
# 31                            Opened Thursday, Nov 16            1
# 32                                                NaN            1
# 33                           Brewery opened June 2019            1
# 34          Opened Oct 2020, Formerly Omaha Ale Works            1
# 35  Largest production facility in the state; Papi...            1
# 36                                                NaN            1
# 37                                  Opened April 2020            1
# 38                                                NaN            1
# 39  A few house brews with a bunch of other stuff ...            1
# 40                                                NaN            1
# 41                                    Opened May 2019            1
# 42                                             Winery            2
# 43                                                NaN            1
# 44                                                NaN            1
# 45                                    Opened Dec 2020            1
# 46                                             Winery            1
# 47                                                NaN            1
# 48                                  Opened March 2019            1
# 49                                                NaN            4
# 50                                    Opened Jan 2021            1
# 51  4-5 rotating seasonals and 8 house beers. Omah...            1
# 52                                                NaN            1
# 53                                                NaN            2
# 54                               Beer Hall added 2016            4
#
#                                             Locations
# 0                                             Lincoln
# 1                                               Omaha
# 2                           Lincoln / Lincoln - South
# 3                                           Valentine
# 4                                              Taylor
# 5                                              Seward
# 6                                            Alliance
# 7                                    Omaha - Downtown
# 8                                            Atkinson
# 9                                        Johnson Lake
# 10                                            Lincoln
# 11                                            Lincoln
# 12                                            Lincoln
# 13                                            Norfolk
# 14                                Lincoln - Haymarket
# 15                                          Fairfield
# 16                                    Omaha - Midtown
# 17                                           Hastings
# 18                                        Scottsbluff
# 19                                           Columbus
# 20                                    Omaha / Lincoln
# 21                                           Imperial
# 22                                             Albion
# 23  Benson / Omaha - SW / Omaha - Little Bohemia /...
# 24                                       Omaha - West
# 25                                              Wayne
# 26                                            Elkhorn
# 27                Broken Bow / Grand Island / Lincoln
# 28                                            LaVista
# 29                                             Ohiowa
# 30                                             McCook
# 31                                           Holdrege
# 32                                            LaVista
# 33                                          Lexington
# 34                                              Omaha
# 35                                            LaVista
# 36                                       North Platte
# 37                                       North Platte
# 38                                          Papillion
# 39                                            Kearney
# 40                                       Grand Island
# 41                                           Syracuse
# 42                              Pawnee City / Lincoln
# 43                                                Ord
# 44                                    Omaha - Midtown
# 45                                              Omaha
# 46                                        Springfield
# 47                                           Hastings
# 48                                           Beatrice
# 49  Kearney / Omaha - West / Omaha - Downtown / Ax...
# 50                                            Kearney
# 51                                   Omaha - Downtown
# 52                                              Omaha
# 53                      Lincoln / Lincoln - Haymarket
# 54  Lincoln - West / Lincoln - SE (Beer Hall) / Om...

# %%
breweriesDF.to_csv('WEB_NEbeerReddit.csv', index=False)
