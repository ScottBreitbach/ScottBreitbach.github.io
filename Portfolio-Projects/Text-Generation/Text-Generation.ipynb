# %% [markdown]
# # Scott Breitbach
# ## 28-May-2022
# # LSTM AI Text Generator
# ## Trained using text of *The Ultimate Hitchiker's Guide to the Galaxy* by Douglas Adams
# Source [text](https://archive.org/stream/TheultimateHitchhikersGuide/The%20Hitchhiker%27s%20Guide%20To%20The%20Galaxy_djvu.txt).

# %% [markdown]
# ## Get the data

# %%
# Load libraries
import tensorflow as tf
import keras
import numpy as np
from keras import layers

# set seed
np.random.seed(seed=42)

# %% [markdown]
# Load data to local notebook:

# %%
# # Load text
# path = 'data/h2g2.txt'
# text = open(path).read().lower()
# print(f'Corpus length: {len(text)}')

# %% [markdown]
# Load data to google colab:

# %%
# import files to colab
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  
def load_text(path):
  # load text data
  text = open(path).read().lower()
  return text

# load the dataframe
text = load_text('/content/h2g2.txt')
print(f'Corpus length: {len(text)}')
# Out:
#      <input type="file" id="files-db817fa7-6880-4f24-ab8a-ddbb8e9cbb1c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-db817fa7-6880-4f24-ab8a-ddbb8e9cbb1c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving h2g2.txt to h2g2.txt
# User uploaded file "h2g2.txt" with length 1603672 bytes
# Corpus length: 1561841

# %% [markdown]
# ## Vectorize the text

# %%
# Vectorizing sequences of characters
maxlen = 60     # Extract sequences of 60 characters
step = 3        # Sample a new sequence every three characters
sentences = []  # Holds extracted sequences
next_chars = [] # Holds targets (the follow-up characters)

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

print(f'Number of sequences: {len(sentences)}')

# List of unique characters in the corpus
chars = sorted(list(set(text))) 
print(f'Unique characters: {len(chars)}')

# Dict that maps unique characters to their index in the list `chars`
char_indices = dict((char, chars.index(char)) for char in chars) 

print('Vectorization...')
# One-hot encodes the caracters into binary arrays:
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=bool)
y = np.zeros((len(sentences), len(chars)), dtype=bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
        y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 520594
# Unique characters: 58
# Vectorization...

# %% [markdown]
# ## Set up the model

# %%
# Set up single-layer LSTM model for next-character prediction
model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
# Model compilation configuration
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    '''
    Sample the next character given the model's predictions
    '''
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# ## Fit the model
# Note: the text turned to gibberish around Epoch 25, so I set it to stop early at Epoch 23.

# %%
# Text-generation loop
import random
import sys
for epoch in range(1, 23):#60): # Trains model for 60 epochs
    print(f'\nEpoch {epoch}:')
    model.fit(x, y, batch_size=128, epochs=1) # Fits model for 1 iteration of data
    # Generate example text every third epoch while training:
    if epoch % 3 == 0:
        # Selects a text seed at random:
        start_index = random.randint(0, len(text) - maxlen - 1)
        generated_text = text[start_index: start_index + maxlen]
        print(f'---\nGenerating with seed:\n"{generated_text}"\n---')
        for temperature in [0.2, 0.5, 1.0]:#, 1.2]: # Tries a range of different sampling temperatures
            print(f'\n------ temperature: {temperature}\n')
            sys.stdout.write(generated_text)
            for i in range(200): # Generates 200 characters, starting from seed text
                # One-hot encodes characters generated so far:
                sampled = np.zeros((1, maxlen, len(chars)))
                for t, char in enumerate(generated_text):
                    sampled[0, t, char_indices[char]] = 1.
                # Samples the next character
                preds = model.predict(sampled, verbose=0)[0]
                next_index = sample(preds, temperature)
                next_char = chars[next_index]
                generated_text += next_char
                generated_text = generated_text[1:]
                sys.stdout.write(next_char)
            print()
# Out:
# Epoch 1:
# 4068/4068 [==============================] - 42s 9ms/step - loss: 1.7398
#
# Epoch 2:
# 4068/4068 [==============================] - 35s 8ms/step - loss: 1.4923
#
# Epoch 3:
# 4068/4068 [==============================] - 35s 9ms/step - loss: 1.4279
# ---
# Generating with seed:
# " of the corridor leading at right angles from
# this one, he "
# ---
#
# ------ temperature: 0.2
#
#  of the corridor leading at right angles from
# this one, he had been and the silence that the back the staring
# the picked and started to the more the stare and the start of
# the stare of the start the start of the properly that the problem
# said that the more
#
# ------ temperature: 0.5
#
# e start of the properly that the problem
# said that the more where it the started to the sturises.
#
# "you don't came to the gargence the other world."
#
# "i think you said the dead whell i was any planet you think
# you mean which the ground it more doing on a m
#
# ------ temperature: 1.0
#
# et you think
# you mean which the ground it more doing on a more where are
# plurately shade ouclizantred and and on the be now un's monthee
# a three whic jump contering heress that had a a leselverside trashing seal
# threat was eejoy patred sig, he forgly by a
#
# Epoch 4:
# 4068/4068 [==============================] - 35s 9ms/step - loss: 1.3987
#
# Epoch 5:
# 4068/4068 [==============================] - 37s 9ms/step - loss: 1.3798
#
# Epoch 6:
# 4068/4068 [==============================] - 39s 10ms/step - loss: 1.3666
# ---
# Generating with seed:
# "arge tank of yellow
# liquid-
#
# emergency suspension tank.
#
# "
# ---
#
# ------ temperature: 0.2
#
# arge tank of yellow
# liquid-
#
# emergency suspension tank.
#
#
#
# "they were something we they were they they were they were something
# some way and they were they were something they want to come
# them to the ship of the subbur and they want to say they want
# the
#
# ------ temperature: 0.5
#
# o the ship of the subbur and they want to say they want
# the earth and they want to a curre of the galaxy they says a
# father slightly boys of the galaxy was and the ship of the ship
# one thing they had they stopped again, and who was say of the
# representant
#
# ------ temperature: 1.0
#
# ad they stopped again, and who was say of the
# representant apparent had itchngents it fied notual thought, it
# appeared there over for all exyutions.
#
# "in their wall," he added, was baced and jumpaiched into the
# despion that deplested so from.
#
# cinceptered
#
# Epoch 7:
# 4068/4068 [==============================] - 35s 9ms/step - loss: 1.3567
#
# Epoch 8:
# 4068/4068 [==============================] - 36s 9ms/step - loss: 1.3497
#
# Epoch 9:
# 4068/4068 [==============================] - 35s 9ms/step - loss: 1.3435
# ---
# Generating with seed:
# "nce this was clearly not
# true the whole thing had eventuall"
# ---
#
# ------ temperature: 0.2
#
# nce this was clearly not
# true the whole thing had eventually seemed to be stared and
# seemed to be someone with the start in the strange to the stars
# stare and started to be continued and started to be the and
# they stopped and started to have a start of the
#
# ------ temperature: 0.5
#
#  be the and
# they stopped and started to have a start of the stire and the
# both and its even that it was because the dim poured to him
# they were something and recested out of the ship.
#
# "you work."
#
# "where i don't itd mouse back they were completely stared
#
# ------ temperature: 1.0
#
#
#
# "where i don't itd mouse back they were completely stared and a
# minusantly through the unacked slunger afterina whichfu rist is a very wrecking on
# an eadre werments for the time to say off it avoiced the mood
# greenedpy rassed, had a startis which looped
#
# Epoch 10:
# 4068/4068 [==============================] - 36s 9ms/step - loss: 1.3387
#
# Epoch 11:
# 4068/4068 [==============================] - 36s 9ms/step - loss: 1.3347
#
# Epoch 12:
# 4068/4068 [==============================] - 36s 9ms/step - loss: 1.3326
# ---
# Generating with seed:
# "'re resigned to doing that anyway, you don't actually
# need "
# ---
#
# ------ temperature: 0.2
#
# 're resigned to doing that anyway, you don't actually
# need to something we've got the and the sense of the distance
# of the ship was anything was anything was a startless of the
# startless of the moment of the moment of the ship was the ship
# was the streen o
#
# ------ temperature: 0.5
#
# ent of the moment of the ship was the ship
# was the streen of the close he had been finally all the ship
# and became to conspect be the first and streen.
#
# "oh," he said, "the moment of some thundent of the infinite
# the million the only walls of the moment of
#
# ------ temperature: 1.0
#
# of the infinite
# the million the only walls of the moment of virality. but fenchurch ypuss. it meant, it
# don'tous, didn't it room this, be youd distinving these in viously one.
#
# , sallarteyessonage. didn't fould
#
#
# there mugglast percetunce when there had no
#
# Epoch 13:
# 4068/4068 [==============================] - 36s 9ms/step - loss: 1.3270
#
# Epoch 14:
# 4068/4068 [==============================] - 35s 9ms/step - loss: 1.3268
#
# Epoch 15:
# 4068/4068 [==============================] - 36s 9ms/step - loss: 1.3221
# ---
# Generating with seed:
# "salesmen, personnel officers, security guards,
# public relat"
# ---
#
# ------ temperature: 0.2
#
# salesmen, personnel officers, security guards,
# public relation the stars of the startled and the stars of the
# concerness of the stars of the startled and started to the start
# and started to the stars of the startled and the stars of the
# startled and the st
#
# ------ temperature: 0.5
#
# rs of the startled and the stars of the
# startled and the starstord of the stars of the galaxy started to
# the very beging of the repthtcirs of the guide to get the spaceship
# had the couple of the time and as the chays and shouting and
# with a man in the ship
#
# ------ temperature: 1.0
#
# me and as the chays and shouting and
# with a man in the ship.
#
# mere ocpeared over and the explaia.
#
# the planet the little and paster and could mark specked in his
# teuse, the particu. sipe of the bunch, and explained at this time
# fiquiner heally, suddenly w
#
# Epoch 16:
# 4068/4068 [==============================] - 37s 9ms/step - loss: 1.3218
#
# Epoch 17:
# 4068/4068 [==============================] - 35s 9ms/step - loss: 1.3232
#
# Epoch 18:
# 4068/4068 [==============================] - 37s 9ms/step - loss: 1.3185
# ---
# Generating with seed:
# "eved or irate.
#
# "ok," said tricia. "give me ten minutes."
# "
# ---
#
# ------ temperature: 0.2
#
# eved or irate.
#
# "ok," said tricia. "give me ten minutes."
#
# "what?"
#
# "what?"
#
# "what?"
#
# "what do you d
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log
# ippend a president of the man was a small thing
# and the ship was a sigh that the president of the planet that
# the ship was a ship, and he was a sign of t
#
# ------ temperature: 0.5
#
# the planet that
# the ship was a ship, and he was a sign of the head and stared
# to him was extremely peardled a point that the standing shadance
# little again, arthur was startled and bitromating a sightly
# because.
#
#
#
# his body and the barman spacefresss and
#
# ------ temperature: 1.0
#
# ghtly
# because.
#
#
#
# his body and the barman spacefresss and visible up prology frown
# the bright out zetre evil expects in a villager savamuled around
# them nexished the shapes of this watches as he shouting at the
# tiny greatalily and carecreily eyes after a
#
# Epoch 19:
# 4068/4068 [==============================] - 35s 9ms/step - loss: 1.3091
#
# Epoch 20:
# 4068/4068 [==============================] - 35s 9ms/step - loss: 1.3223
#
# Epoch 21:
# 4068/4068 [==============================] - 36s 9ms/step - loss: 1.3292
# ---
# Generating with seed:
# "py, come
# now."
#
# the robot let out a long heartfelt sigh of"
# ---
#
# ------ temperature: 0.2
#
# py, come
# now."
#
# the robot let out a long heartfelt sigh of the stars of the
# man was the standing and he was a start and the stars of the
# start of the police standing and started to the stars of the
# beam and the stars of the man was a start of the stars of
#
# ------ temperature: 0.5
#
# e
# beam and the stars of the man was a start of the stars of the
# mind of the rest and this he was handward.
#
# "i don't one that this in the stars, in the ship. i can some
# managed and sandwiches of silling in the one. the strange of the
# stars of missing rema
#
# ------ temperature: 1.0
#
# illing in the one. the strange of the
# stars of missing remank was bursing. still winds and this dolphized
# to your another your thremmpocalleting in which arrivabe it unceripration.
# wosi in cruck. he gave some sgly, more and heads through yory
# bettered some
#
# Epoch 22:
# 4068/4068 [==============================] - 35s 9ms/step - loss: 1.3226

# %% [markdown]
# ## Generate text:

# %%
# Selects a text seed at random:
start_index = random.randint(0, len(text) - maxlen - 1)
generated_text = text[start_index: start_index + maxlen]
print(f'---\nGenerating with seed:\n"{generated_text}"\n---')
for temperature in [0.2, 0.5, 1.0]: # Tries a range of different sampling temperatures
    print(f'\n------ temperature: {temperature}\n')
    sys.stdout.write(generated_text)
    for i in range(400): # Generates 400 characters, starting from seed text
        # One-hot encodes characters generated so far:
        sampled = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(generated_text):
            sampled[0, t, char_indices[char]] = 1.
        # Samples the next character
        preds = model.predict(sampled, verbose=0)[0]
        next_index = sample(preds, temperature)
        next_char = chars[next_index]
        generated_text += next_char
        generated_text = generated_text[1:]
        sys.stdout.write(next_char)
    print()
# Out:
# ---
# Generating with seed:
# "g against the very, very dim perimeter of the field. he
# hel"
# ---
#
# ------ temperature: 0.2
#
# g against the very, very dim perimeter of the field. he
# held to the sign of the sign of the moment of the problem of
# the particular of the silent was the stars of the moment of
# the ground of the strange of the perfectly of the ship was the
# star was the star and stared to the star.
#
# "the mininges," said zaphod, "the stars of the point of the
# star to the ship was the speculation of the moment of the mind
# was the stars of the stars of the stars of the
#
# ------ temperature: 0.5
#
# of the mind
# was the stars of the stars of the stars of the computer and
# simply field to consect as if
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log
#  he could travely and seemed to
# speak and he said, and had the sitting for a problem and suddenly
# a point with the thought was his own spit of perfectly moment
# door of the little help to speak by the old man and when it
# was silently off the ship on the moment of the stars of the
# planet and suspended it or anything because the some problem.
#
# a couple
#
# ------ temperature: 1.0
#
# uspended it or anything because the some problem.
#
# a couple of point had mananged a moments of the deye of elbogyantast
# futh, he looked to his brase at him excoired out of the legal pitter
# to the goftet, span as he should have forgage a perfectly when
# it wasn't his e,r he "i'm anything? revolated enbricked donem."
#
# the raper tway.
#
# destained violentous brand to her.
#
# "you tell foo," said zaphod, aok, well, possible. and hat.
#
# "it isn't came on in a

# %% [markdown]
# ## Generate 20 samples:

# %%
for i in range(0,20):
    print(f'\n== GENERATED TEXT #{i+1}: ==\n')
    # Selects a text seed at random:
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print(f'---\nGenerating with seed:\n"{generated_text}"\n---\n')
    temperature = 0.5
    sys.stdout.write(generated_text)
    for i in range(400): # Generates 400 characters, starting from seed text
        # One-hot encodes characters generated so far:
        sampled = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(generated_text):
            sampled[0, t, char_indices[char]] = 1.
        # Samples the next character
        preds = model.predict(sampled, verbose=0)[0]
        next_index = sample(preds, temperature)
        next_char = chars[next_index]
        generated_text += next_char
        generated_text = generated_text[1:]
        sys.stdout.write(next_char)
    print()
# Out:
# == GENERATED TEXT #1: ==
#
# ---
# Generating with seed:
# "ud."
#
# "in, as you say it, the mud."
#
# as soon as mr. prosse"
# ---
#
# ud."
#
# "in, as you say it, the mud."
#
# as soon as mr. prosser and was the man down the blinding of
# the planet speaker that he was the large mind that he was not
# the moment, and breaked the sound of prolied and many of when
# the first thing he was an instance of the consider in the party-out
# provid, which he stood of the land of the moment into the man
# and the furrow.
#
# "what would be getting that just the building."
#
# "he foo, the see-to him to the sta
#
# == GENERATED TEXT #2: ==
#
# ---
# Generating with seed:
# "ugh what slartibartfast had assured him was five-dimensional"
# ---
#
# ugh what slartibartfast had assured him was five-dimensional
# of the sound of the star started to po-chaper from the hand was
# the problems as she was so the first and for a cold had to say
# the moment of a star and in the moment of the signoom of visible to
# way to see the structure of the cabin of presinalately to carried
# across t
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log
# he point of the strange and disappeared to all the polite
# and all the strong piles of the moment of a completely furness
# of
#
# == GENERATED TEXT #3: ==
#
# ---
# Generating with seed:
# "en the dominant life form.
#
# so how would such a mistake ari"
# ---
#
# en the dominant life form.
#
# so how would such a mistake arish parts of the signous to speak
# the televolding sitting the sea managed because was it as it
# was he stood and strugged at the sound of president and silent
# salid on the moment the signough of the same way, and the world
# ford and as a featires of spaceship of first and pinked sigh
# right strange of the man all and tried to coffee anything down the
# design and it was going to see the ship was t
#
# == GENERATED TEXT #4: ==
#
# ---
# Generating with seed:
# "
# in the fall of 1979, the first hitchhiker book was publishe"
# ---
#
#
# in the fall of 1979, the first hitchhiker book was published and brain the light
# second the side of the man was the captain to the whole and
# constructing had something all arthur was anywhere to past to
# do his head was concent universe.
#
# the ship was into the cabin and so finalled and should the
# other realise of the computer and as the answer.
#
# "final and everything out in the street of the wind and stepped
# to seems are struck to the tables, the ga
#
# == GENERATED TEXT #5: ==
#
# ---
# Generating with seed:
# " time you went off home sir?"
#
# "i'm trying to baby, i'm try"
# ---
#
#  time you went off home sir?"
#
# "i'm trying to baby, i'm trying to see it was the way," said ford,
# she had not the thing were anything in the bit of the superphot
# and he could a glass, and the light had been instanced them
# and said the account of the galactic way, and over he so all
# the world in the other for the solar hand she stood and love
# and anything and because the sandwich all in the animal that the
# a companication of the stars of the small mo
#
# == GENERATED TEXT #6: ==
#
# ---
# Generating with seed:
# "i was built
# with no filters at all, which means i perceive "
# ---
#
# i was built
# with no filters at all, which means i perceive the party of
# something to the guide of the mattres to speed to the perfectly
# of the hundred to be started to say it was the end of the problems
# spaceship of the girl of the first of the tapped and saying
# the account, his sandwich patterns the dark deparmant of the
# guard of the moment and the speculation of the polite of the
# small heaptir here was anything he had been gone in the street
# of t
#
# == GENERATED TEXT #7: ==
#
# ---
# Generating with seed:
# "
# death of president yooden vranx. you remember yooden, ford?"
# ---
#
#
# death of president yooden vranx. you remember yooden, ford?"
#
# "i mean it was didn't he was a mind and shoulder. carried to
# not the moment and because he found his head was another sands
# again.
#
# "hey, what was sin?"
#
# "we said so feeling of something to the fumber of the first
# space-slight picked at his head and he too, and had tried to be
# and the same of a space-to him to the personal little for the
# back of the streat he stood of the next strong li
#
# == GENERATED TEXT #8: ==
#
# ---
# Generating with seed:
# "al
# laughter which came drifting from prak's cabin at the fa"
# ---
#
# al
# laughter which came drifting from prak's cabin at the fact that
# she seemed to be speed. and the universe of the ground of the
# first specule.
#
# "i would a stritt designed like back, he was easion was to the
# door was silently into the guard to the rock that he was an
# annount of the computer was because an impossible and it was
# particularly to the reservous couck or innoor in the little
# because the but anything he didn't the hollow form and he had
#
#
# == GENERATED TEXT #9: ==
#
# ---
# Generating with seed:
# " craving for company became too
# great they would know where"
# ---
#
#  craving for company became too
# great they would know where he had been norished at the one
# to his head was an except of the planet of the planet of the
# search of the bit of meaning another to sit something and she
# stood and reached to the restoub of the first of the moment,
# but and she was a few to the back of the but he said it was
# figured the same to show him down the change of a couple of
# few his attention and should mind the days of the alien s
#
# == GENERATED TEXT #10: ==
#
# ---
# Generating with seed:
# "."
#
# "fun?" yelped arthur. "fun!" fie quickly checked out of"
# ---
#
# ."
#
# "fun?" yelped arthur. "fun!" fie quickly checked out of the
# war and slightly to his conlockering into the sound of the ground.
#
# "the least the other star strange of the ground of the ship.
#
# "where was a expericiness of the siming to deforme the problem.
#
# "but they stood of the stars of saying to a memory the an and
# the slight shook of perfectly finally at the man more. he said,
# which was siremed and stuff on the same of the moment to say
# start
#
# == GENERATED TEXT #11: ==
#
# ---
# Generating with seed:
# "o say that it is a very great
# pleasure, honour and privileg"
# ---
#
# o say that it is a very great
# pleasure, honour and privilege. it was the man been any dammenses
# that the along from one comport and what he had ever be the
# stractions of perfectly here and little she were a good of mellished
# search and moment of the business of the image of the point
# of the head and the guide had over the problem of probable sitting
# on the stars in the problem of the specute and standing of the
# charance of the sense of ground.
#
# "bu
#
# == GENERATED TEXT #12: ==
#
# ---
# Generating with seed:
# " grip on things and start making some positive
# moves and th"
# ---
#
#  grip on things and start making some positive
# moves and the guidar top of the one of the man was a sunging
# the way to deep so the
#
#
#
# silent was was the ship was anything down the other world the
# buzzer saying, the man was over that the perfectly infinitel's
# from party with a man seemed to be the distance, and well, which
# the point of the same of the president of the same from with
# suppretcis, and he said the see-to stood at the potical moment
# and
#
# == GENERATED TEXT #13: ==
#
# ---
# Generating with seed:
# "ng it all of a sudden.
# what do you think i am, completely w"
# ---
#
# ng it all of a sudden.
# what do you think i am, completely with long that they maker
# anything and with the fact which the wall speed of the memory
# of the suppresinant than it was the strange door, he thought
# and impossible finally stories to be funnered to take the moment
# saying when anything exactly the slight things that he was that
# the problems of the grip of except to do at light in the restouht of the
# paralately and the benemering something the
#
# == GENERATED TEXT #14: ==
#
# ---
# Generating with seed:
# "nto a kind of determined cheeriness. he said that he was
# be"
# ---
#
# nto a kind of determined cheeriness. he said that he was
# because the small to the said to her feeling for to be prefects
# of the moment of the small past sounds, and minered that was
# said and a moment and as they were going to see it.
#
# he stopped and the stars of the generry and explaced possibit
# hemitary down and in a slight the little with the sension of
# a super continued and he should a bewilderful a couple of moment
# with the specist of the rest o
#
# == GENERATED TEXT #15: ==
#
# ---
# Generating with seed:
# " little figure to himself.
#
# "yeah," said zaphod, "er, how i"
# ---
#
#  little figure to himself.
#
# "yeah," said zaphod, "er, how it mean," said zaphod to the first
# and the picture faint stood and finally.
#
# "but that i might be the computer was the guide and stood of
# the speciely and britioned and was the bright to probably have
# anythed in the sound of the moment, and what a very trave and
# definitely and consoliding to connice the and the sensation
# that an restaurant to conseforied the perfectly water fool in
# the stree
#
# == GENERATED TEXT #16: ==
#
# ---
# Generating with seed:
# " in
# appearance except for the extra head and third arm. his"
# ---
#
#  in
# appearance except for the extra head and third arm. his head
# and mush to realise to the single specker stared to come of
# a past in the ship was finally to the a continue and seems something
# that the robot was the street and saying was the pack of sun
# of wink.
#
# "come on," said arthur, but stared and said the restaurant to
# him an another of the links. he looked at it and beginngo the
# particular form with the back of the but it was seemed to speak
#
# == GENERATED TEXT #17: ==
#
# ---
# Generating with seed:
# "ck-up personality that i thought might work out better."
#
# ""
# ---
#
# ck-up personality that i thought might work out better."
#
# "he want to think it wasn't something we was was the planet
# was the ship to him he said, "it's that i spen called to like the
# door of a space-teleport of the a little of the siribarly trees
# calpily perhaps and been the ship was he had been the place
# to a sweets was a distance of the strange of the fool, so his single
# concern single moment of the exist any silent and replaced the
# silence of st
#
# == GENERATED TEXT #18: ==
#
# ---
# Generating with seed:
# "flexibly and imaginatively, and also, it seemed, to be shock"
# ---
#
# flexibly and imaginatively, and also, it seemed, to be shocked
# to the screen of the man was the tried to meet the things of
# his through the concent of the moment and had the rest of the
# supersible was the moment of the party of the sanding of visible of the
# restaurant of the computer of the betiel the moment and the
# universe of the botton and sank, and yesure of the universe
# and suppress the star and anywhere, but the problem of the great
# computer t
#
# == GENERATED TEXT #19: ==
#
# ---
# Generating with seed:
# "e had taken
# his damaged knives over to the forge bright and"
# ---
#
# e had taken
# his damaged knives over to the forge bright and started to want
# to soft of problem of the office he would have to see them on the
# said, "i should the moment of the little ships of ringer.
#
# he was was tried to could anything that he was a speculation of
# the batterns and the valley to the battles from her like a before the
# sense of the state and sense which was didn't was after the
# perfectly personality of its two a pub the stars of the st
#
# == GENERATED TEXT #20: ==
#
# ---
# Generating with seed:
# "ry hard on the other and when the sun rose the following
# mo"
# ---
#
# ry hard on the other and when the sun rose the following
# moment of the light and part of the black of the one to him
# he looked at him something we to the book of the smile.
#
# called to trillian a doubs to the moment in a small moment of
# series of the rest of the rest of the star was and and there was
# concent of the problem in the same currental of the problem of the
# brings had got and was experienced, and gave the signoom. he
# said, as an other happy
